# %%
#request the url with id of the organism
#Example 
# https://www.lesarchivesduspectacle.net/?IDX_Organisme=439&Saison=2008
# Arsenal id 439
# import the library we use to open URLs
import urllib.request
import re
import pandas as pd
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
organism="439"
saison="2010"
# specify which URL/web page we are going to be scraping
url = "https://www.lesarchivesduspectacle.net/?IDX_Organisme=" + organism + "&Saison=" + saison
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")
#the div where the information is
div_interested = soup.find('div', id='async-org-saison-annee')
table = div_interested.find_all('table')[0] # Grab the first table 
df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 
                           'performanceId', 'author', 'authordId', 'genre', 'period', 'occurency','place'])
row_marker = 0
for row in table.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        organism_id  = organism
        year = saison
        if(column_marker == 0):
            genre = columns[0].get_text()
            #parse the first td performance - performanceId 
            performance_element = columns[0].find('a',class_='c_Spectacle')
            if(performance_element):
                performance = performance_element.contents[0]
                performanceId = performance_element['href']
                #parse the first td author - authorId
            author_element = columns[0].find('a',class_='c_Personne')
            if(author_element):
                author = author_element.contents[0]
                authorId = author_element['href']
        else:
            if(column_marker == 1):
                period = columns[1].get_text()
            if(column_marker == 2):
                occurency = columns[2].get_text()       
            if(column_marker == 3):
                place= columns[3].get_text()
        column_marker += 1
    df = df.append({'organism_id': organism_id, 'year': year, 'performance': performance,'performanceId': performanceId,'author' : author, 'authordId':  authorId, 'genre': genre, 'period': period, 'occurency':occurency,'place':place}, ignore_index=True) # yuck         
    period=""
    occurency=""
    place=""
    genre=""
    performance=""
    performanceId=""
    author=""
    authorId=""
    row_marker += 1

df
# Out:
#    organism_id  year                               performance  \
# 0          439  2010                             Babel (Words)
# 1          439  2010                   Pour l'amour de Cosette
# 2          439  2010                                Nearly 90²
# 3          439  2010                                       LOL
# 4          439  2010                                  Asphalte
# 5          439  2010                                     Zaïna
# 6          439  2010                              Cribles/Live
# 7          439  2010                             L'Île solaire
# 8          439  2010                            L'Ombre double
# 9          439  2010                             Chouf Ouchouf
# 10         439  2010                                    Ismène
# 11         439  2010                     (Sacrées) sorcières !
# 12         439  2010  Parades and Changes, replay in expansion
# 13         439  2010                              Déva-Kitatom
# 14         439  2010
# 15         439  2010
# 16         439  2010                                   Savanna
# 17         439  2010                              Madame Plaza
# 18         439  2010                                 Pacifique
#
#             performanceId                 author             authordId  \
# 0   /?IDX_Spectacle=23453   Sidi Larbi Cherkaoui   /?IDX_Personne=4676
# 1   /?IDX_Spectacle=30546            Victor Hugo  /?IDX_Personne=10155
# 2   /?IDX_Spectacle=19502       Merce Cunningham   /?IDX_Personne=4182
# 3   /?IDX_Spectacle=12451         Bintou Dembélé  /?IDX_Personne=54983
# 4   /?IDX_Spectacle=20185           Pierre Rigal   /?IDX_Personne=4737
# 5    /?IDX_Spectacle=6692        Lucette Salibur  /?IDX_Personne=49151
# 6   /?IDX_Spectacle=30548       Emmanuelle Huynh  /?IDX_Personne=22947
# 7   /?IDX_Spectacle=13345        Michel Tournier  /?IDX_Personne=40742
# 8   /?IDX_Spectacle=30549            Odile Duboc    /?IDX_Personne=640
# 9   /?IDX_Spectacle=20081
# 10  /?IDX_Spectacle=12559          Yannis Ritsos  /?IDX_Personne=20943
# 11  /?IDX_Spectacle=30550
# 12  /?IDX_Spectacle=34525            Anne Collod  /?IDX_Personne=51866
# 13  /?IDX_Spectacle=30551
# 14
# 15
# 16  /?IDX_Spectacle=35475             Amit Drori  /?IDX_Personne=50349
# 17  /?IDX_Spectacle=17503       Bouchra Ouizguen  /?IDX_Personne=13141
# 18  /?IDX_Spectacle=28494  Nasser Martin-Gousset   /?IDX_Personne=5024
#
#                                                 genre             period  \
# 0   \nBabel (Words)  chorégraphie Sidi Larbi Cherk...  \n08/10 → 09/10\n
# 1   \nPour l'amour de Cosette d'après Victor Hugo ...  \n29/10 → 30/10\n
# 2       \nNearly 90²  chorégraphie Merce Cunningham\n          \n20/11\n
# 3                \nLOL  chorégraphie Bintou Dembélé\n          \n24/11\n
# 4   \nAsphalte  chorégraphie Pierre Rigal concepti...          \n27/11\n
# 5   \nZaïna de Lucette Salibur mise en scène Chris...          \n18/12\n
# 6     \nCribles/Live  chorégraphie Emmanuelle Huynh\n          \n26/01\n
# 7   \nL'Île solaire d'après Michel Tournier mise e...          \n02/02\n
# 8   \nL'Ombre double  chorégraphie Odile Duboc con...          \n11/02\n
# 9                                   \nChouf Ouchouf\n  \n16/02 → 17/02\n
# 10  \nIsmène de Yannis Ritsos mise en scène Enrico...  \n23/02 → 25/02\n
# 11                          \n(Sacrées) sorcières !\n          \n26/02\n
# 12  \nParades and Changes, replay in expansion  co...          \n14/04\n
# 13                                   \nDéva-Kitatom\n          \n16/04\n
# 14
# 15                                       \nPassages\n
# 16  \nSavanna  mise en scène Amit Drori conception...  \n17/05 → 19/05\n
# 17    \nMadame Plaza  chorégraphie Bouchra Ouizguen\n          \n20/05\n
# 18  \nPacifique  chorégraphie Nasser Martin-Gousset\n          \n09/06\n
#
#              occurency                                place
# 0             [2 rep.]                  \n (Grande salle)\n
# 1             [2 rep.]              \n”  (Grande salle)\n\n
# 2             [1 rep.]              \n”  (Grande salle)\n\n
# 3   [1 rep. + 2 scol.]              \n”  (Grande salle)\n\n
# 4             [1 rep.]              \n”  (Grande salle)\n\n
# 5   [1 rep. + 1 scol.]  \nSalle Saint-Pierre-aux-Nonnains\n
# 6             [1 rep.]                  \n (Grande salle)\n
# 7             [1 rep.]              \n”  (Grande salle)\n\n
# 8             [1 rep.]              \n”  (Grande salle)\n\n
# 9             [2 rep.]              \n”  (Grande salle)\n\n
# 10            [3 rep.]             \nNEST\n  (Thionville)\n
# 11  [1 rep. + 2 scol.]          \n (Salle de l'Esplanade)\n
# 12            [1 rep.]                  \n (Grande salle)\n
# 13  [1 rep. + 2 scol.]          \n (Salle de l'Esplanade)\n
# 14
# 15
# 16            [3 rep.]          \n (Salle de l'Esplanade)\n
# 17            [1 rep.]                  \n (Grande salle)\n
# 18            [1 rep.]                  \n (Grande salle)\n

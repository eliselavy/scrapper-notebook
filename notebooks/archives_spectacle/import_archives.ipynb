# %%
#For one organism and one year

# %%
#request the url with id of the organism
#Example 
# https://www.lesarchivesduspectacle.net/?IDX_Organisme=439&Saison=2008
# Arsenal id 439
# import the library we use to open URLs
import urllib.request
import re
import pandas as pd
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
organism="439"
saison="2016"
# specify which URL/web page we are going to be scraping
url = "https://www.lesarchivesduspectacle.net/?IDX_Organisme=" + organism + "&Saison=" + saison
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")
#the div where the information is
div_interested = soup.find('div', id='async-org-saison-annee')
table = div_interested.find_all('table')[0] # Grab the first table 
df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 
                           'performanceId', 'author', 'authordId', 'label', 'period', 'occurency','place'])
row_marker = 0
period=""
occurency=""
place=""
label=""
performance=""
performanceId=""
author=""
authorId=""
for row in table.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        organism_id  = int(organism)
        year = saison
        if(column_marker == 0):
            label = columns[0].get_text()
            #parse the first td performance - performanceId 
            performance_element = columns[0].find('a',class_='c_Spectacle')
            if(performance_element):
                performance = performance_element.contents[0]
                href_val_perf=performance_element['href'].replace("/?IDX_Spectacle=","")
                if href_val_perf.isdigit():
                    performanceId = int(href_val_perf)
                    #parse the first td author - authorId
                author_element = columns[0].find('a',class_='c_Personne')
                if(author_element):
                    author = author_element.contents[0]
                    href_val_auth=author_element['href'].replace("/?IDX_Personne=","")
                    if href_val_auth.isdigit():
                        authorId = int(href_val_auth)
        else:
            if(column_marker == 1):
                period = columns[1].get_text()
            if(column_marker == 2):
                occurency = columns[2].get_text()       
            if(column_marker == 3):
                initial= columns[3].get_text()
                #remove special caracter ” before strip
                place = initial.replace("”", "")
                place= place.strip()
        column_marker += 1
    df = df.append({'organism_id': organism_id, 'year': year, 'performance': performance,'performanceId': performanceId,'author' : author, 'authordId':  authorId, 'label': label, 'period': period, 'occurency':occurency,'place':place}, ignore_index=True) # yuck         
    period=""
    occurency=""
    place=""
    label=""
    performance=""
    performanceId=""
    author=""
    authorId=""
    row_marker += 1

#df = df[df['place'] != ""]
#df.groupby("place")["year"].count()
df
# Out:
#    organism_id  year                        performance performanceId  \
# 0          439  2016           Orfeo, par-delà le Gange         74340
# 1          439  2016                           Pavement         58370
# 2          439  2016                            Noctura         53079
# 3          439  2016                        Pied de nez         74341
# 4          439  2016                Ballet  de Lorraine         74342
# 5          439  2016
# 6          439  2016
# 7          439  2016  Magnificences à la cour de France         74343
# 8          439  2016            Le Festin de l'araignée         74347
# 9          439  2016   Vingt mille lieues sous les mers         65537
# 10         439  2016                            Mass B.         66193
# 11         439  2016                 Influences latines         67918
# 12         439  2016        Si Peau d'Âne m'était conté         69685
# 13         439  2016              Le Mouvement de l'air         66405
# 14         439  2016                        La Création         74335
# 15         439  2016                     Nicht schlafen         73219
# 16         439  2016                               Gold         68422
# 17         439  2016                 Entre chou et loup         53094
# 18         439  2016
# 19         439  2016
# 20         439  2016                           Al Atlal         80771
# 21         439  2016                                 um         73845
# 22         439  2016                               Exil         81073
# 23         439  2016                                  ”
# 24         439  2016
# 25         439  2016
# 26         439  2016                          Fractus V         68670
# 27         439  2016                      Sous la neige         67807
# 28         439  2016                Pictures of America         82326
#
#                    author authordId  \
# 0      Claudio Monteverdi      4953
# 1            Kyle Abraham    169563
# 2            Romain Henry    137487
# 3          Aurélie Gandit     57989
# 4
# 5
# 6
# 7       Philippe Vallepin     83792
# 8
# 9             Jules Verne     16237
# 10        Béatrice Massin      9908
# 11
# 12  Marie-Geneviève Massé     33844
# 13          Yan Raballand      8234
# 14           Joseph Haydn      9846
# 15           Alain Platel     14757
# 16            Emanuel Gat     43955
# 17        Laurence Garcia      6801
# 18
# 19
# 20           Ibrahim Nagi    231502
# 21           Zad Moultaka     25569
# 22          Smaïn Laacher    137364
# 23          Smaïn Laacher    137364
# 24
# 25
# 26   Sidi Larbi Cherkaoui      4676
# 27      Martine Waniowski    149633
# 28         Claire Gibault     48443
#
#                                                 label  \
# 0   \nOrfeo, par-delà le Gange musique Claudio Mon...
# 1             \nPavement  chorégraphie Kyle Abraham\n
# 2              \nNoctura  chorégraphie Romain Henry\n
# 3   \nPied de nez  chorégraphie Aurélie Gandit con...
# 4                             \nBallet  de Lorraine\n
# 5
# 6                             \nLa Couleur des Sons\n
# 7   \nMagnificences à la cour de France  mise en s...
# 8                         \nLe Festin de l'araignée\n
# 9   \nVingt mille lieues sous les mers de Jules Ve...
# 10  \nMass B.  chorégraphie Béatrice Massin concep...
# 11                             \nInfluences latines\n
# 12  \nSi Peau d'Âne m'était conté  chorégraphie Ma...
# 13  \nLe Mouvement de l'air  chorégraphie Yan Raba...
# 14  \nLa Création musique Joseph Haydn mise en scè...
# 15      \nNicht schlafen  chorégraphie Alain Platel\n
# 16                 \nGold  chorégraphie Emanuel Gat\n
# 17  \nEntre chou et loup  mise en scène Laurence G...
# 18
# 19                                       \nPassages\n
# 20  \nAl Atlal d'après Ibrahim Nagi conception Nor...
# 21                    \num  conception Zad Moultaka\n
# 22  \nExil d'après Smaïn Laacher… mise en scène Sa...
# 23  \n”\nExil d'après Smaïn Laacher… mise en scène...
# 24
# 25                               \nEast Block Party\n
# 26   \nFractus V  chorégraphie Sidi Larbi Cherkaoui\n
# 27  \nSous la neige  mise en scène Martine Waniows...
# 28  \nPictures of America  conception Claire Gibau...
#
#                             period           occurency  \
# 0                \n29/09 → 01/10\n  [1 rep. + 2 scol.]
# 1                        \n07/10\n            [1 rep.]
# 2                        \n13/10\n  [1 rep. + 1 scol.]
# 3                \n03/11 → 05/11\n  [1 rep. + 3 scol.]
# 4                        \n18/11\n            [1 rep.]
# 5
# 6
# 7                        \n01/12\n            [1 rep.]
# 8                        \n10/12\n            [1 rep.]
# 9                \n05/01 → 06/01\n  [1 rep. + 2 scol.]
# 10                       \n13/01\n            [1 rep.]
# 11                       \n04/02\n            [1 rep.]
# 12               \n26/02 → 28/02\n  [1 rep. + 1 scol.]
# 13                       \n10/03\n  [1 rep. + 1 scol.]
# 14                       \n16/03\n            [1 rep.]
# 15               \n31/03 → 01/04\n            [2 rep.]
# 16                       \n06/04\n            [1 rep.]
# 17               \n26/04 → 27/04\n  [1 rep. + 2 scol.]
# 18
# 19
# 20                       \n07/05\n            [1 rep.]
# 21                       \n10/05\n            [1 rep.]
# 22                       \n13/05\n            [1 rep.]
# 23                       \n13/05\n            [1 rep.]
# 24
# 25
# 26                       \n09/06\n            [1 rep.]
# 27               \n16/06 → 17/06\n  [1 rep. + 2 scol.]
# 28  \n20/12 → ...\n
#
#                       place
# 0            (Grande salle)
# 1            (Grande salle)
# 2    (Studio du Gouverneur)
# 3    (Studio du Gouverneur)
# 4            (Grande salle)
# 5
# 6
# 7            (Grande salle)
# 8            (Grande salle)
# 9            (Grande salle)
# 10           (Grande salle)
# 11           (Grande salle)
# 12           (Grande salle)
# 13           (Grande salle)
# 14           (Grande salle)
# 15           (Grande salle)
# 16           (Grande salle)
# 17   (Salle de l'Esplanade)
# 18
# 19
# 20   (Salle de l'Esplanade)
# 21   (Salle de l'Esplanade)
# 22   (Salle de l'Esplanade)
# 23  (Salon Claude Lefebvre)
# 24
# 25
# 26           (Grande salle)
# 27           (Grande salle)
# 28

# %%
#request the url with id of the film
#Example 
# http://earlycinema.dch.phil-fak.uni-koeln.de/films/view/1
# import the library we use to open URLs
import urllib.request
import re
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
import pandas as pd


def import_df_performance(organismId,saison):
    # specify which URL/web page we are going to be scraping
    url = "https://www.lesarchivesduspectacle.net/?IDX_Organisme=" + organismId + "&Saison=" + saison
    # open the url using urllib.request and put the HTML into the page variable
    #catch exception some case id doesn't exist cf 970
    try:
        # open the url using urllib.request and put the HTML into the page variable
        page = urllib.request.urlopen(url)
        # parse the HTML from our URL into the BeautifulSoup parse tree format
        soup = BeautifulSoup(page, "lxml")
        #the div where the information is
        div_interested = soup.find('div', id='async-org-saison-annee')
        table = div_interested.find_all('table')[0] # Grab the first table 
        df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 
                           'performanceId', 'author', 'authordId', 'label', 'period', 'occurency','place'])
        row_marker = 0
        period=""
        occurency=""
        place=""
        label=""
        performance=""
        performanceId=0
        author=""
        authorId=0
        for row in table.find_all('tr'):
            column_marker = 0
            columns = row.find_all('td')
            for column in columns:
                organism_id  = organismId
                year = saison
                if(column_marker == 0):
                    label = columns[0].get_text()
                    #parse the first td performance - performanceId 
                    performance_element = columns[0].find('a',class_='c_Spectacle')
                    if(performance_element):
                        performance = performance_element.contents[0]
                        href_val_perf=performance_element['href'].replace("/?IDX_Spectacle=","")
                        if href_val_perf.isdigit():
                            performanceId = int(href_val_perf)
                        #parse the first td author - authorId
                    author_element = columns[0].find('a',class_='c_Personne')
                    if(author_element):
                        author = author_element.contents[0]
                        href_val_auth=author_element['href'].replace("/?IDX_Personne=","")
                        if href_val_auth.isdigit():
                            authorId = int(href_val_auth)
                else:
                    if(column_marker == 1):
                        period = columns[1].get_text()
                    if(column_marker == 2):
                        occurency = columns[2].get_text()       
                    if(column_marker == 3):
                        initial= columns[3].get_text()
                        #remove special caracter ” before strip
                        place = initial.replace("”", "")
                        place= place.strip()
                column_marker += 1
            df = df.append({'organism_id': organism_id, 'year': year, 'performance': performance,'performanceId': performanceId,'author' : author, 'authordId':  authorId, 'label': label, 'period': period, 'occurency':occurency,'place':place}, ignore_index=True) # yuck         
            period=""
            occurency=""
            place=""
            label=""
            performance=""
            performanceId=0
            author=""
            authorId=0
            row_marker += 1
        return df
    except urllib.error.URLError as e:
        print(e.reason + "for organismId "  + organismId + " saison " + saison)

# %%
#call the function
import time
from datetime import datetime
df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 'performanceId', 'author', 'authordId', 'label', 'period', 'occurency','place'])                        
print("start",datetime.now()) 
# 439 Arsenal
# 699 CCAM [Centre culturel André Malraux] - Scène Nationale de Vandoeuvre-lès-Nancy
organismId="439"
# 1744 Pôle sud
# 465 Le Manège de Reims
# 1914 Carreau forbach  
# 383 Grand théâtre du Luxembourg 
for saison in range(2010,2020):
    try:
        df=df.append(import_df_performance(organismId, str(saison)),sort=False,ignore_index=True)
    except (ValueError,IOError) as err:
        print(err)
    except:
        print("Problem with organismId %s and saison %s" % (organismId,str(saison)))
        raise
df.to_csv('all_10_years_organism_' + organismId + '.csv')

print("finish",datetime.now())
# Out:
# start 2020-07-21 18:16:13.445297
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# finish 2020-07-21 18:16:20.477069

# %%
#from a spectacleId retrieve genre and country
#spectacleId 22463
# import the library we use to open URLs
import urllib.request
import re
import pandas as pd
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
#spectacleId="22463"
spectacleId="28494"
# specify which URL/web page we are going to be scraping
url = "https://www.lesarchivesduspectacle.net/?IDX_Spectacle=" + spectacleId
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")
#the div where the information is
#the div where the information is
div_interested = soup.find('div', class_='fiche__footer')
table = div_interested.find_all('table')[0] # Grab the first table   
df = pd.DataFrame(columns=['spectacleId','genre', 'duration', 'country'])
row_marker = 0
for row in table.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        spectacleId = spectacleId
        if(column_marker == 0):
            label = columns[0].get_text()
            #parse the first td performance - performanceId 
            performance_element = columns[0].find('a',class_='c_Spectacle')
            if(performance_element):
                performance = performance_element.contents[0]
                performanceId = performance_element['href'].replace("/?IDX_Spectacle=","")
                #parse the first td author - authorId
            author_element = columns[0].find('a',class_='c_Personne')
            if(author_element):
                author = author_element.contents[0]
                authorId = author_element['href'].replace("/?IDX_Personne=","")
            else:
                if(column_marker == 1):
                    period = columns[1].get_text()
                if(column_marker == 2):
                    occurency = columns[2].get_text()       
                if(column_marker == 3):
                    place= columns[3].get_text()
            column_marker += 1
        df = df.append({'spectacleId': spectacleId, 'genre': genre, 'duration': duration,'country': country}, ignore_index=True) # yuck         
        genre=""
        duration=""
        country=""
        row_marker += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fabe50aef156> in <module>
#      46                     place= columns[3].get_text()
#      47             column_marker += 1
# ---> 48         df = df.append({'spectacleId': spectacleId, 'genre': genre, 'duration': duration,'country': country}, ignore_index=True) # yuck
#      49         genre=""
#      50         duration=""
#
# NameError: name 'genre' is not defined

# %%
import urllib.request
import re
import pandas as pd
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
#spectacleId="34525"
#spectacleId="36956"
spectacleId="20185"
# specify which URL/web page we are going to be scraping
url = "https://www.lesarchivesduspectacle.net/?IDX_Spectacle=" + spectacleId
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")
#the div where the information is
#the div where the information is
div_interested = soup.find('div', class_='fiche__footer') 
column_label=[]
column_value=[]
for row in div_interested.find_all('table')[0].findAll('tr'):
    th = row.findAll('th')[0].contents[0]
    td = row.findAll('td')[0].contents[0]
    column_label.append(th)
    column_value.append(td)
new_table = pd.DataFrame(columns=column_label, index= [0]) # I know the size
for row in div_interested.find_all('table')[0].findAll('tr'):
    th = row.findAll('th')[0].contents[0]
    td = row.findAll('td')[0].contents[0]
    new_table.at[0,th] = td
new_table["spectacleId"]=spectacleId
#Recuperer creation_date - organism_creation 
#the div where the information is
div_spectacle = soup.find('div', id='div_Spectacle')
p_spectacle = div_spectacle.find_all('p')[0]
if(p_spectacle):
    for time in p_spectacle.findAll('time'):
        if time.has_attr('datetime'):
            new_table["typeDate"]=time.previousSibling
            new_table["date"]=time['datetime']
    for organism in p_spectacle.findAll('a',class_ ='c_Organisme'):
        if organism.has_attr('href'):
            new_table["organismeId"]=organism['href']
            new_table["organismeName"]=organism.contents[0].strip()
new_table["to_analyse"]=p_spectacle.contents[0].strip()
new_table
#table[0] class="f-spectacle__equipe"    table[1]  class="f-spectacle__equipe"  
table_production = div_spectacle.find_all('table')[2]
print(table_production)
# Out:
# <table style="margin:20px 0 20px 0;">
# <tr>
# <td valign="top">Production
#                 </td>
# <td valign="top">
# <a class="c_Organisme b" href="?IDX_Organisme=2092">Compagnie Dernière Minute</a><span class="em09 n">  (Toulouse)</span>
# </td></tr>
# </table>

# %%
#the div where the information is
div_interested = soup.find('div', class_='div_Spectacle')

# %%
#For one organism and one year

# %%
#request the url with id of the organism
#Example 
# https://www.lesarchivesduspectacle.net/?IDX_Organisme=439&Saison=2008
# Arsenal id 439
# import the library we use to open URLs
import urllib.request
import re
import pandas as pd
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
organism="1914"
saison="2011"
# specify which URL/web page we are going to be scraping
url = "https://www.lesarchivesduspectacle.net/?IDX_Organisme=" + organism + "&Saison=" + saison
# open the url using urllib.request and put the HTML into the page variable
page = urllib.request.urlopen(url)
# parse the HTML from our URL into the BeautifulSoup parse tree format
soup = BeautifulSoup(page, "lxml")
#the div where the information is
div_interested = soup.find('div', id='async-org-saison-annee')
table = div_interested.find_all('table')[0] # Grab the first table 
df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 
                           'performanceId', 'author', 'authordId', 'label', 'period', 'occurency','place'])
row_marker = 0
for row in table.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        organism_id  = organism
        year = saison
        if(column_marker == 0):
            label = columns[0].get_text()
            #parse the first td performance - performanceId 
            performance_element = columns[0].find('a',class_='c_Spectacle')
            if(performance_element):
                performance = performance_element.contents[0]
                performanceId = performance_element['href'].replace("/?IDX_Spectacle=","")
                #parse the first td author - authorId
            author_element = columns[0].find('a',class_='c_Personne')
            if(author_element):
                author = author_element.contents[0]
                authorId = author_element['href'].replace("/?IDX_Personne=","")
        else:
            if(column_marker == 1):
                period = columns[1].get_text()
            if(column_marker == 2):
                occurency = columns[2].get_text()       
            if(column_marker == 3):
                place= columns[3].get_text()
        column_marker += 1
    df = df.append({'organism_id': organism_id, 'year': year, 'performance': performance,'performanceId': performanceId,'author' : author, 'authordId':  authorId, 'label': label, 'period': period, 'occurency':occurency,'place':place}, ignore_index=True) # yuck         
    period=""
    occurency=""
    place=""
    label=""
    performance=""
    performanceId=""
    author=""
    authorId=""
    row_marker += 1

df
# Out:
#    organism_id  year                      performance performanceId  \
# 0         1914  2011                Franchise postale         22463
# 1         1914  2011                        La Maison          3262
# 2         1914  2011                     Living Rooms         37982
# 3         1914  2011          Le Temps de l'innocence         37983
# 4         1914  2011            Effraction de l'oubli         37984
# 5         1914  2011               Les Dames du jeudi         22424
# 6         1914  2011
# 7         1914  2011
# 8         1914  2011        Si bleue, si bleue la mer         37985
# 9         1914  2011             L'Opéra de quat'sous         36026
# 10        1914  2011        Une vendeuse d'allumettes         11676
# 11        1914  2011                         Na grani         28678
# 12        1914  2011         Du goudron et des plumes         19833
# 13        1914  2011                Quartier lointain         11306
# 14        1914  2011                            Hulul         28389
# 15        1914  2011  Le Gros, la Vache et le Mainate         27539
# 16        1914  2011      L'Intrépide Soldat de plomb         13032
# 17        1914  2011                           Violet         36370
# 18        1914  2011       Vaterland, le pays du père         22224
# 19        1914  2011                 Album de famille         29209
# 20        1914  2011                    Tout un homme         36401
# 21        1914  2011                    Vertical Road         29844
# 22        1914  2011           Par hasard et pas rasé         36075
# 23        1914  2011         Les Fourberies de Scapin          6525
# 24        1914  2011          La Courtisane amoureuse         21030
# 25        1914  2011                   Paroles gelées         36369
# 26        1914  2011                          Au-delà         36956
# 27        1914  2011                       Sacrifices          7181
# 28        1914  2011
# 29        1914  2011
# 30        1914  2011                           Le Pli         37987
# 31        1914  2011
# 32        1914  2011
# 33        1914  2011              Le Cirque invisible           321
# 34        1914  2011                       Cendrillon         36033
# 35        1914  2011                           Farben         36400
#
#                      author authordId  \
# 0            Pierre Richard     39570
# 1          Marguerite Duras       159
# 2             Cécile Backès      3213
# 3            Michèle Meftah    127542
# 4             Camille Mutel     60990
# 5              Loleh Bellon      2313
# 6
# 7
# 8       Nis-Momme Stockmann    127547
# 9            Bertolt Brecht       308
# 10  Hans Christian Andersen      8571
# 11           Mickaël Le Mer     37958
# 12           Mathurin Bolze       993
# 13           Jirô Taniguchi     51118
# 14             Arnold Lobel      9134
# 15          Pierre Guillois      3753
# 16  Hans Christian Andersen      8571
# 17                Jon Fosse       837
# 18         Jean-Paul Wenzel      2429
# 19              Edy Legrand    104297
# 20         Jean-Paul Wenzel      2429
# 21               Akram Khan      4674
# 22       Camille Grandville       706
# 23                  Molière       199
# 24      Jean de La Fontaine      1705
# 25        François Rabelais      5483
# 26         Koen Augustijnen       433
# 27          Pierre Guillois      3753
# 28
# 29
# 30              Laura Arend    127550
# 31
# 32
# 33   Jean-Baptiste Thierrée      1422
# 34         Charles Perrault      7679
# 35        Mathieu Bertholet     11712
#
#                                                 label             period  \
# 0   \nFranchise postale de Pierre Richard… mise en...          \n24/09\n
# 1   \nLa Maison d'après Marguerite Duras mise en s...  \n13/10 → 18/10\n
# 2       \nLiving Rooms  mise en scène Cécile Backès\n          \n21/10\n
# 3   \nLe Temps de l'innocence  chorégraphie Michèl...          \n04/11\n
# 4   \nEffraction de l'oubli  chorégraphie Camille ...          \n04/11\n
# 5   \nLes Dames du jeudi de Loleh Bellon mise en s...          \n10/11\n
# 6
# 7                                        \nPrimeurs\n
# 8   \nSi bleue, si bleue la mer de Nis-Momme Stock...          \n16/11\n
# 9   \nL'Opéra de quat'sous de Bertolt Brecht mise ...  \n24/11 → 25/11\n
# 10  \nUne vendeuse d'allumettes d'après Hans Chris...  \n29/11 → 02/12\n
# 11          \nNa grani  chorégraphie Mickaël Le Mer\n  \n06/12 → 07/12\n
# 12  \nDu goudron et des plumes  conception Mathuri...  \n13/12 → 14/12\n
# 13  \nQuartier lointain d'après Jirô Taniguchi mis...  \n05/01 → 06/01\n
# 14  \nHulul d'après Arnold Lobel mise en scène Fré...  \n09/01 → 13/01\n
# 15  \nLe Gros, la Vache et le Mainate de Pierre Gu...  \n19/01 → 20/01\n
# 16  \nL'Intrépide Soldat de plomb d'après Hans Chr...  \n24/01 → 27/01\n
# 17  \nViolet d'après Jon Fosse mise en scène Béran...  \n08/02 → 09/02\n
# 18  \nVaterland, le pays du père d'après Jean-Paul...          \n28/02\n
# 19  \nAlbum de famille d'après Edy Legrand mise en...  \n06/03 → 08/03\n
# 20  \nTout un homme d'après Jean-Paul Wenzel mise ...  \n09/03 → 17/03\n
# 21         \nVertical Road  chorégraphie Akram Khan\n          \n13/03\n
# 22  \nPar hasard et pas rasé  mise en scène Camill...          \n23/03\n
# 23  \nLes Fourberies de Scapin d'après Molière mis...  \n27/03 → 29/03\n
# 24  \nLa Courtisane amoureuse de Jean de La Fontai...          \n30/03\n
# 25  \nParoles gelées d'après François Rabelais mis...          \n05/04\n
# 26         \nAu-delà  chorégraphie Koen Augustijnen\n          \n24/04\n
# 27  \nSacrifices de Pierre Guillois… mise en scène...          \n27/04\n
# 28
# 29                                \nBataille de Rue\n
# 30               \nLe Pli  chorégraphie Laura Arend\n          \n11/05\n
# 31
# 32                          \nPerspectives Festival\n
# 33  \nLe Cirque invisible  mise en scène Jean-Bapt...  \n24/05 → 26/05\n
# 34  \nCendrillon d'après Charles Perrault… mise en...  \n31/05 → 01/06\n
# 35  \nFarben de Mathieu Bertholet mise en scène Vé...  \n05/06 → 06/06\n
#
#    occurency                                        place
# 0   [1 rep.]                                           \n
# 1             \nen décentralisation dans l'Eurodistrict\n
# 2   [1 rep.]                                           \n
# 3   [1 rep.]                                           \n
# 4   [1 rep.]                                           \n
# 5   [1 rep.]                                           \n
# 6
# 7
# 8   [1 rep.]                        \nétape de création\n
# 9   [2 rep.]                                           \n
# 10  [6 rep.]                                           \n
# 11  [2 rep.]                                           \n
# 12  [2 rep.]                                           \n
# 13  [2 rep.]                                           \n
# 14            \nen décentralisation dans l'Eurodistrict\n
# 15  [2 rep.]                                           \n
# 16  [7 rep.]                                           \n
# 17  [2 rep.]                                           \n
# 18  [1 rep.]                                           \n
# 19  [5 rep.]                                           \n
# 20  [6 rep.]                                           \n
# 21  [1 rep.]                                           \n
# 22  [1 rep.]                                           \n
# 23  [3 rep.]                                           \n
# 24  [1 rep.]                                           \n
# 25  [1 rep.]                                           \n
# 26  [1 rep.]                                           \n
# 27  [1 rep.]                                           \n
# 28
# 29
# 30  [1 rep.]                                           \n
# 31
# 32
# 33  [3 rep.]                                           \n
# 34  [2 rep.]                                           \n
# 35  [2 rep.]                                           \n

# %%
#request the url with id of the film
#Example 
# http://earlycinema.dch.phil-fak.uni-koeln.de/films/view/1
# import the library we use to open URLs
import urllib.request
import re
# import the BeautifulSoup library so we can parse HTML and XML documents
from bs4 import BeautifulSoup
import pandas as pd


def import_df_performance(organismId,saison):
    # specify which URL/web page we are going to be scraping
    url = "https://www.lesarchivesduspectacle.net/?IDX_Organisme=" + organismId + "&Saison=" + saison
    # open the url using urllib.request and put the HTML into the page variable
    #catch exception some case id doesn't exist cf 970
    try:
        # open the url using urllib.request and put the HTML into the page variable
        page = urllib.request.urlopen(url)
        # parse the HTML from our URL into the BeautifulSoup parse tree format
        soup = BeautifulSoup(page, "lxml")
        #the div where the information is
        div_interested = soup.find('div', id='async-org-saison-annee')
        table = div_interested.find_all('table')[0] # Grab the first table 
        df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 
                           'performanceId', 'author', 'authordId', 'label', 'period', 'occurency','place'])
        row_marker = 0
        for row in table.find_all('tr'):
            column_marker = 0
            columns = row.find_all('td')
            for column in columns:
                organism_id  = organismId
                year = saison
                if(column_marker == 0):
                    label = columns[0].get_text()
                    #parse the first td performance - performanceId 
                    performance_element = columns[0].find('a',class_='c_Spectacle')
                    if(performance_element):
                        performance = performance_element.contents[0]
                        performanceId = performance_element['href'].replace("/?IDX_Spectacle=","")
                        #parse the first td author - authorId
                    author_element = columns[0].find('a',class_='c_Personne')
                    if(author_element):
                        author = author_element.contents[0]
                        authorId = author_element['href'].replace("/?IDX_Personne=","")
                else:
                    if(column_marker == 1):
                        period = columns[1].get_text()
                    if(column_marker == 2):
                        occurency = columns[2].get_text()       
                    if(column_marker == 3):
                        place= columns[3].get_text()
                column_marker += 1
            df = df.append({'organism_id': organism_id, 'year': year, 'performance': performance,'performanceId': performanceId,'author' : author, 'authordId':  authorId, 'label': label, 'period': period, 'occurency':occurency,'place':place}, ignore_index=True) # yuck         
            period=""
            occurency=""
            place=""
            label=""
            performance=""
            performanceId=""
            author=""
            authorId=""
            row_marker += 1
        return df
    except urllib.error.URLError as e:
        print(e.reason + "for organismId "  + organismId + " saison " + saison)

# %%
#call the function
import time
from datetime import datetime
df = pd.DataFrame(columns=['organism_id', 'year', 'performance', 'performanceId', 'author', 'authordId', 'label', 'period', 'occurency','place'])                        
print("start",datetime.now())   
organismId="1914"
saison="2011"
try:
    df=df.append(import_df_performance(organismId, saison),sort=False,ignore_index=True)
except:
    print("problem with organism" , organismId)
    raise
df.to_csv('organism_' + organismId + '_' + saison + '.csv')

print("finish",datetime.now())
# Out:
# start 2020-07-04 13:41:32.118429
# finish 2020-07-04 13:41:32.780123

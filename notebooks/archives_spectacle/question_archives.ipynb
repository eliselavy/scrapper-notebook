# %%
# ORGANISM ID DE L'ETUDE
# 439 Arsenal
# 699 CCAM [Centre culturel André Malraux] - Scène Nationale de Vandoeuvre-lès-Nancy
# 383 Grand théâtre du Luxembourg
# 1914 Carreau forbach  

# ORGANISM ID QUI PEUVENT ETRE PARTENAIRE
# 1744 Pôle sud
# 465 Le Manège de Reims


#to save the figure
#fig = ax.get_figure()
#fig.savefig('plot1.png')

# %%
#Quelles sont les 20 premiers chorégraphes les plus invités?

# %%
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.set_index(['performanceId'], drop=True, inplace=True)

#df_organism.authordId.value_counts()

df_organism.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

#df_organism.groupby(["author"]).author.count().sort_values(ascending=False).head(20)

# %%
#Look at for the year of the choreograph the most invited
# pour arsenal
#913       6 keresmacker
#57989     5 gandit
#3647      4 gruel
#11289     4 François Chaignaud
import pandas as pd
csv_file_path = "all_10_years_organism_439_convertInt.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['authordId'].isin([11289])]
df_organism

# %%
# pour arsenal
913       6 keresmacker
57989     5 gandit
3647      4 gruel
11289     4 François Chaignaud

#pour ccam
19142      7 marie cambois
60990      5 camille mutel
3647       5 Aurore Gruel
4837       5 Olga Mesa

#pour grand theatre
913       10 keermacker
1029       8 shaekesapare
9098       6 Sasha Waltz
11883      5 wagner

#pour le carreau
# 1914 Carreau forbach 
37958     4 Mickaël Le Mer
199       4 Moliere
2717      3 Wim Vandekeybus
16498     3 Nicolas Lambert

# %%
#Pour l'Arsenal voir les utilisations de salle Grande Salle - Studio du Gouverneur  - BAM
# 439 Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism = df_organism[['year', 'performanceId','place']]
#remove the performance without place
df_organism = df_organism[df_organism['place'] != ""]
#df_organism.groupby("place")["year"].count()
#df_organism = df_organism[df_organism['place'].isin(["(Grande salle)"])]
repartition_place =df_organism.groupby(["place"]).performanceId.count().sort_values(ascending=False).head(20)
ax= repartition_place.plot.bar(
legend=False,
    rot=10, # rotate tick labels on x axis
    figsize=(16, 14),
    fontsize="9" # try changing to 9, 14, 26
)
# set a readable title for the plot
ax.set_title('Nombre de spectacles par salle')

# label the y axis
ax.set_ylabel('')

# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('salle')

# %%
#Michèle Paradon besoin d'une salle avec une jauge plus petite - voir l'utilisation au cours des années

import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
filter_salle = [
    "(Grande salle)",
    "(Studio du Gouverneur)",
    "(Salle de l'Esplanade)",
    "La BAM",
    "Salle Saint-Pierre-aux-Nonnains",
]

salle_use = pd.pivot_table(
    salle_zoom_df,
    index='place',
    aggfunc={'organism_id': 'count'}
).rename(columns={'organism_id':'size'})


salle_zoom_df = df_organism[df_organism.place.isin(filter_salle)]
# let's reshape the data
# to make plotting easier
axes = salle_zoom_df.hist(
    column='year',
    by='place',
    sharex=False,
    sharey=True,
    figsize=(8,8),
)

# %%
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
#df_organism = df_organism[df_organism['place'].isin(["(Grande salle)"])]
df_organism = df_organism[df_organism['year'].isin(["2018"])]
df_organism
# Out:
#      Unnamed: 0  organism_id  year  \
# 161         161          439  2018
# 162         162          439  2018
# 163         163          439  2018
# 164         164          439  2018
# 165         165          439  2018
# 166         166          439  2018
# 167         167          439  2018
# 168         168          439  2018
# 169         169          439  2018
# 170         170          439  2018
# 171         171          439  2018
# 172         172          439  2018
# 173         173          439  2018
# 174         174          439  2018
# 175         175          439  2018
# 176         176          439  2018
# 177         177          439  2018
# 178         178          439  2018
# 179         179          439  2018
# 180         180          439  2018
# 181         181          439  2018
# 182         182          439  2018
# 183         183          439  2018
# 184         184          439  2018
# 187         187          439  2018
# 188         188          439  2018
# 189         189          439  2018
# 190         190          439  2018
# 193         193          439  2018
# 194         194          439  2018
# 195         195          439  2018
#
#                                            performance  performanceId  \
# 161                                    Counter Phrases          68361
# 162                              L'Opéra du roi soleil          90779
# 163                            Perchée dans les arbres          90517
# 164                                          Ad noctum          66093
# 165                                              Works          83976
# 166                                        Oscar Piano          76074
# 167                                   Hors-champ 14-18          90780
# 168                                    My (petit) Pogo          75395
# 169                                            Narcose          74090
# 170                                   Bonjour la neige          72019
# 171                  Polichinelle et Orphée aux enfers          85046
# 172                                       Manipulation          90781
# 173                                          L'Au-delà          90398
# 174                                    Requiem pour L.          86085
# 175                                     Belles et bois          74725
# 176                                          Inaudible          72386
# 177                                      Ma mère l'Oye          83777
# 178                                             Phèdre          76492
# 179                                               Play          30910
# 180         Blanche-Neige ou la Chute du mur de Berlin          65530
# 181  L'Histoire probable de la musique électronique...          82017
# 182                                          Zeitigung          80188
# 183                                          Sugarland          83384
# 184                                        Danser Casa          87796
# 187                                        Danser Casa          87796
# 188                                             X-Adra          81742
# 189  And so you see...our honourable blue sky and e...          72221
# 190                                           Monstres          80888
# 193                                              Crowd          83328
# 194                                               Kata          80401
# 195                                            L'Arbre          54137
#
#                          author  authordId  \
# 161  Anne Teresa De Keersmaeker        913
# 162                Marin Marais      10404
# 163              Aurélie Gandit      57989
# 164             Christian Rizzo       7929
# 165                 Emanuel Gat      43955
# 166              Adrien Chanson      98360
# 167       Étienne Nicolas Méhul      86983
# 168          Fabrice Ramalingom        150
# 169               Aïcha M'Barek       9314
# 170                         NaN          0
# 171                Marco Horvat      14341
# 172                Aurore Gruel       3647
# 173       Didier-Georges Gabily      21591
# 174                Alain Platel      14757
# 175          Emmanuelle Vo-Dinh       8590
# 176               Thomas Hauert      14728
# 177             Élodie Fondacci     237816
# 178       Jean-Baptiste Lemoyne     220205
# 179      Shantala Shivalingappa       6436
# 180              Samuel Hercule      82035
# 181        Matthias Kristalsson     234329
# 182  Anne Teresa De Keersmaeker        913
# 183           Martine Waniowski     149633
# 184                 Kader Attou       9325
# 187                 Kader Attou       9325
# 188              Ramzi Choukair      28374
# 189                 Robyn Orlin       4798
# 190        DeLaVallet Bidiefono      49122
# 193              Jeanne Azoulay     163631
# 194                 Anne Nguyen      42974
# 195             Isabelle Bernay     167044
#
#                                                  label             period  \
# 161  \nCounter Phrases  chorégraphie Anne Teresa De...          \n26/09\n
# 162  \nL'Opéra du roi soleil musique Marin Marais…\...          \n27/09\n
# 163  \nPerchée dans les arbres  chorégraphie Auréli...  \n11/10 → 12/10\n
# 164        \nAd noctum  chorégraphie Christian Rizzo\n          \n18/10\n
# 165                \nWorks  chorégraphie Emanuel Gat\n          \n10/11\n
# 166  \nOscar Piano d’Adrien Chanson… mise en scène ...  \n16/11 → 17/11\n
# 167  \nHors-champ 14-18 musique Étienne Nicolas Méh...          \n21/11\n
# 168  \nMy (petit) Pogo  chorégraphie Fabrice Ramali...  \n21/11 → 22/11\n
# 169  \nNarcose  chorégraphie Aïcha M'Barek… concept...          \n15/12\n
# 170                               \nBonjour la neige\n  \n21/12 → 22/12\n
# 171  \nPolichinelle et Orphée aux enfers de Marco H...  \n09/01 → 10/01\n
# 172  \nManipulation  chorégraphie Aurore Gruel conc...  \n10/01 → 11/01\n
# 173  \nL'Au-delà de Didier-Georges Gabily mise en s...  \n30/01 → 01/02\n
# 174    \nRequiem pour L.  mise en scène Alain Platel\n  \n01/02 → 02/02\n
# 175  \nBelles et bois  conception Emmanuelle Vo-Din...  \n24/02 → 25/02\n
# 176  \nInaudible  chorégraphie Thomas Hauert concep...          \n15/03\n
# 177  \nMa mère l'Oye d’Élodie Fondacci conception J...  \n15/03 → 16/03\n
# 178  \nPhèdre musique Jean-Baptiste Lemoyne mise en...          \n24/03\n
# 179  \nPlay  chorégraphie Shantala Shivalingappa…\n...  \n30/03 → 31/03\n
# 180  \nBlanche-Neige ou la Chute du mur de Berlin d...          \n01/04\n
# 181  \nL'Histoire probable de la musique électroniq...  \n24/04 → 25/04\n
# 182  \nZeitigung  chorégraphie Anne Teresa De Keers...          \n25/04\n
# 183     \nSugarland  mise en scène Martine Waniowski\n  \n26/04 → 27/04\n
# 184  \nDanser Casa  chorégraphie Kader Attou…\n\n  ...          \n07/05\n
# 187  \nDanser Casa  chorégraphie Kader Attou…\n\n  ...          \n07/05\n
# 188  \nX-Adra  mise en scène Ramzi Choukair concept...  \n11/05 → 12/05\n
# 189  \nAnd so you see...our honourable blue sky and...          \n15/05\n
# 190    \nMonstres  chorégraphie DeLaVallet Bidiefono\n          \n16/05\n
# 193  \nCrowd  chorégraphie Jeanne Azoulay…\n\n     ...  \n04/06 → 05/06\n
# 194                 \nKata  chorégraphie Anne Nguyen\n          \n08/06\n
# 195  \nL'Arbre  mise en scène Isabelle Bernay…\n\n ...  \n14/06 → 15/06\n
#
#               occurency                                              place
# 161            [1 rep.]                                     (Grande salle)
# 162            [1 rep.]                                     (Grande salle)
# 163            [2 rep.]                             (Studio du Gouverneur)
# 164            [1 rep.]                                     (Grande salle)
# 165            [1 rep.]                                     (Grande salle)
# 166  [1 rep. + 2 scol.]                                                NaN
# 167            [1 rep.]                                     (Grande salle)
# 168  [1 rep. + 2 scol.]                                             La BAM
# 169            [1 rep.]                                     (Grande salle)
# 170  [1 rep. + 2 scol.]                                    Les Trinitaires
# 171  [1 rep. + 2 scol.]                             (Salle de l'Esplanade)
# 172            [2 rep.]                             (Studio du Gouverneur)
# 173            [3 rep.]                             (Studio du Gouverneur)
# 174            [2 rep.]                                     (Grande salle)
# 175  [1 rep. + 2 scol.]                             (Salle de l'Esplanade)
# 176            [1 rep.]                                     (Grande salle)
# 177  [1 rep. + 2 scol.]                             (Salle de l'Esplanade)
# 178            [1 rep.]                                     (Grande salle)
# 179            [2 rep.]                                     (Grande salle)
# 180            [1 rep.]  Théâtre municipal de Thionville\n  (Thionville...
# 181  [1 rep. + 2 scol.]                                             La BAM
# 182            [1 rep.]                                     (Grande salle)
# 183  [1 rep. + 2 scol.]                             (Studio du Gouverneur)
# 184            [1 rep.]                                     (Grande salle)
# 187            [1 rep.]                                     (Grande salle)
# 188            [2 rep.]                             (Salle de l'Esplanade)
# 189            [1 rep.]                             (Salle de l'Esplanade)
# 190            [1 rep.]                                     (Grande salle)
# 193  [1 rep. + 2 scol.]                                             La BAM
# 194            [1 rep.]                                     (Grande salle)
# 195  [1 rep. + 2 scol.]                             (Studio du Gouverneur)

# %%
#Voir l'évolution des spectacles par an
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
#df_organism.set_index(['performanceId'], drop=True, inplace=True)
#df_organism.groupby(["year"]).plot.bar()
ax=df_organism.groupby("year")["performanceId"].count().plot.bar()
# set a readable title for the plot
ax.set_title('Nombre de spectacles par an')
# label the y axis
ax.set_ylabel('')
# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('année')
df_organism.groupby("year")["performanceId"].count()
# Out:
# year
# 2010    17
# 2011    19
# 2012    15
# 2013    12
# 2014    20
# 2015    13
# 2016    22
# 2017    19
# 2018    31
# 2019    27
# Name: performanceId, dtype: int64

# %%
#Représentation du nombre de spectacles par an pour les 3 structures 
# 439 Arsenal
# 699 CCAM
# 383 grand theatre 
# 1914 CARREAU

#Voir l'évolution des spectacles par an
import pandas as pd
import matplotlib.pyplot as plt
csv_file_path_arsenal = "all_10_years_organism_439.csv"
df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal = df_arsenal[df_arsenal['performanceId'] != 0]
df_arsenal=df_arsenal.groupby("year")["performanceId"].count()


csv_file_path_ccam = "all_10_years_organism_699.csv"
df_ccam = pd.read_csv(csv_file_path_ccam)
df_ccam = df_ccam[df_ccam['performanceId'] != 0]
df_ccam=df_ccam.groupby("year")["performanceId"].count()

csv_file_path_carreau = "all_10_years_organism_1914.csv"
df_carreau = pd.read_csv(csv_file_path_carreau)
df_carreau = df_carreau[df_carreau['performanceId'] != 0]
df_carreau=df_carreau.groupby("year")["performanceId"].count()

csv_file_path_grandtheatre = "all_10_years_organism_383.csv"
df_grandtheatre = pd.read_csv(csv_file_path_grandtheatre)
df_grandtheatre = df_grandtheatre[df_grandtheatre['performanceId'] != 0]
df_grandtheatre=df_grandtheatre.groupby("year")["performanceId"].count()

plt.plot(df_arsenal)
plt.plot(df_ccam)
plt.plot(df_carreau)
plt.plot(df_grandtheatre)

plt.legend(["Arsenal", "CCAM","Carreau","Grand théâtre"])

# %%
#Remarque

#saison 2010-2011 Grand théâtre  pas complète signalée (2010-2011) sur le site
# tous genre confondus pas encore le filtre sur le genre

# %%
# 1744 Pôle sud
# 439 Arsenal
# 465 Le Manège de Reims
# 699 CCAM
# 383 grand theatre 
# voir si regroupement avec les spectaclesId

# %%
#Look at for the year of the choreograph the most invited
# pour arsenal
#913       6 keresmacker
#57989     5 gandit
#3647      4 gruel
#11289     4 François Chaignaud
import pandas as pd
csv_file_path = "all_10_years_organism_439_convertInt.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['authordId'].isin([11289])]
df_organism

# %%
# pour arsenal
913       6 keresmacker
57989     5 gandit
3647      4 gruel
11289     4 François Chaignaud

#pour ccam
19142      7 marie cambois
60990      5 camille mutel
3647       5 Aurore Gruel
4837       5 Olga Mesa

#pour grand theatre
913       10 keermacker
1029       8 shaekesapare
9098       6 Sasha Waltz
11883      5 wagner

#pour le carreau
# 1914 Carreau forbach 
37958     4 Mickaël Le Mer
199       4 Moliere
2717      3 Wim Vandekeybus
16498     3 Nicolas Lambert

# %%
#Pour l'Arsenal voir les utilisations de salle Grande Salle - Studio du Gouverneur  - BAM
# 439 Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.set_index(['performanceId'], drop=True, inplace=True)
df_organism = df_organism[['year', 'performance','place']]
#remove the performance without place
df_organism = df_organism[df_organism['place'] != ""]
#df_organism.groupby("place")["year"].count()
df_organism = df_organism[df_organism['place'].isin(["(Grande salle)"])]
df_organism.groupby(["year"]).place.count().sort_values(ascending=False).head(20).plot.bar()

# %%
# 1744 Pôle sud
# 439 Arsenal
# voir si regroupement avec les spectaclesId

# 465 Le Manège de Reims

# 699 CCAM

# 383 grand theatre

# %%
#Look at for the year of the choreograph the most invited
# pour arsenal
#913       6 keresmacker
#57989     5 gandit
#3647      4 gruel
#11289     4 François Chaignaud
import pandas as pd
csv_file_path = "all_10_years_organism_439_convertInt.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['authordId'].isin([11289])]
df_organism

# %%
# pour arsenal
913       6 keresmacker
57989     5 gandit
3647      4 gruel
11289     4 François Chaignaud

#pour ccam
19142      7 marie cambois
60990      5 camille mutel
3647       5 Aurore Gruel
4837       5 Olga Mesa

#pour grand theatre
913       10 keermacker
1029       8 shaekesapare
9098       6 Sasha Waltz
11883      5 wagner

#pour le carreau
# 1914 Carreau forbach 
37958     4 Mickaël Le Mer
199       4 Moliere
2717      3 Wim Vandekeybus
16498     3 Nicolas Lambert

# %%
#Pour l'Arsenal voir les utilisations de salle Grande Salle - Studio du Gouverneur  - BAM
# 439 Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.set_index(['performanceId'], drop=True, inplace=True)
df_organism = df_organism[['year', 'performance','place']]
#remove the performance without place
df_organism = df_organism[df_organism['place'] != ""]
#df_organism.groupby("place")["year"].count()
df_organism = df_organism[df_organism['place'].isin(["(Grande salle)"])]
df_organism.groupby(["year"]).place.count().head(20).plot.bar()

# %%
# Evolution des spectacles par an Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.groupby(["year"]).place.count().plot.bar()
# Out:
#      Unnamed: 0  organism_id  year         performance  performanceId  \
# 76           76          439  2014           Dumy Moyi          50278
# 91           91          439  2014            Dub Love          59854
# 100         100          439  2015            Dub Love          59854
# 115         115          439  2017  Romances inciertos          81168
#
#                  author  authordId  \
# 76   François Chaignaud      11289
# 91   François Chaignaud      11289
# 100  François Chaignaud      11289
# 115  François Chaignaud      11289
#
#                                                  label     period occurency  \
# 76   \nDumy Moyi  chorégraphie François Chaignaud c...  \n12/12\n  [4 rep.]
# 91   \nDub Love  conception François Chaignaud…\n\n...  \n19/06\n  [1 rep.]
# 100  \nDub Love  conception François Chaignaud…\n\n...  \n04/03\n  [1 rep.]
# 115  \nRomances inciertos  chorégraphie François Ch...  \n15/12\n  [1 rep.]
#
#                                    place
# 76   \nSalle Saint-Pierre-aux-Nonnains\n
# 91           \n (Studio du Gouverneur)\n
# 100              \n”  (Grande salle)\n\n
# 115              \n”  (Grande salle)\n\n

# %%
# pour arsenal
913       6 keresmacker
57989     5 gandit
3647      4 gruel
11289     4 François Chaignaud

#pour ccam
19142      7 marie cambois
60990      5 camille mutel
3647       5 Aurore Gruel
4837       5 Olga Mesa

#pour grand theatre
913       10 keermacker
1029       8 shaekesapare
9098       6 Sasha Waltz
11883      5 wagner

#pour le carreau
# 1914 Carreau forbach 
37958     4 Mickaël Le Mer
199       4 Moliere
2717      3 Wim Vandekeybus
16498     3 Nicolas Lambert

# %%
#Pour l'Arsenal voir les utilisations de salle Grande Salle - Studio du Gouverneur  - BAM
# 439 Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.set_index(['performanceId'], drop=True, inplace=True)
df_organism = df_organism[['year', 'performance','place']]
#remove the performance without place
df_organism = df_organism[df_organism['place'] != ""]
#df_organism.groupby("place")["year"].count()
df_organism = df_organism[df_organism['place'].isin(["(Grande salle)"])]
df_organism.groupby(["year"]).place.count().head(20).plot.bar()

# %%
# Evolution des spectacles par an Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.groupby(["year"]).place.count().plot.bar()

# %%
# 1744 Pôle sud
# 439 Arsenal
# voir si regroupement avec les spectaclesId

# 465 Le Manège de Reims

# 699 CCAM

# 383 grand theatre

# %%
# 1744 Pôle sud
# 439 Arsenal
# voir si regroupement avec les spectaclesId

import pandas as pd

csv_file_path_pole_sud = "all_10_years_organism_699_convertInt.csv"
csv_file_path_arsenal = "all_10_years_organism_1744_convertInt.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

#df_pole_sud.set_index('performanceId', drop=True, inplace=True)
df_pole_sud.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 3

# %%
df_arsenal = df_arsenal.loc[i]
df_arsenal.sort_values(by=['year'])
# Out:
#                     Unnamed: 0  organism_id                     performance  \
# performanceId year
# 37959         2011          37         1744           Cuisses de grenouille
# 82164         2018         201         1744                     Accusations
# 89368         2018         185         1744  Laisse le vent du soir décider
#
#                                 author  authordId  \
# performanceId year
# 37959         2011      Carlotta Sagna       6907
# 82164         2018   Ann Van Den Broek     171494
# 89368         2018  Étienne Fanteguzzi      16533
#
#                                                                 label  \
# performanceId year
# 37959         2011  \nCuisses de grenouille  chorégraphie Carlotta...
# 82164         2018  \nAccusations  chorégraphie Ann Van Den Broek ...
# 89368         2018  \nLaisse le vent du soir décider  chorégraphie...
#
#                                period occurency  \
# performanceId year
# 37959         2011  \n02/04 → 04/04\n  [4 rep.]
# 82164         2018  \n27/03 → 28/03\n  [2 rep.]
# 89368         2018  \n24/01 → 25/01\n  [2 rep.]
#
#                                                    place
# performanceId year
# 37959         2011                                    \n
# 82164         2018            \nThéâtre de Hautepierre\n
# 89368         2018  \nTJP-Grande Scène\n  (Strasbourg)\n

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])
# Out:
#                Unnamed: 0  organism_id  year           performance  \
# performanceId
# 12559                  19          699  2010                Ismène
# 29203                   9          699  2010   Un œil sur la chose
# 36399                  45          699  2011             Le Tribun
# 46999                  62          699  2012                Encore
# 46999                  62          699  2012                Encore
# 46999                  92          699  2013                Encore
# 46999                  92          699  2013                Encore
# 47000                  88          699  2013            De pictura
# 59853                 148          699  2014  Sans territoire fixe
# 59853                 148          699  2014  Sans territoire fixe
# 60718                 127          699  2014    L'Oripeau du Pollu
# 59853                 162          699  2015  Sans territoire fixe
# 59853                 162          699  2015  Sans territoire fixe
# 17503                 263          699  2019          Madame Plaza
# 90781                 290          699  2019          Manipulation
#
#                          author  authordId  \
# performanceId
# 12559             Yannis Ritsos      20943
# 29203           Françoise Klein      22788
# 36399            Lionel Parlier       6446
# 46999              Aurore Gruel       3647
# 46999              Aurore Gruel       3647
# 46999              Aurore Gruel       3647
# 46999              Aurore Gruel       3647
# 47000            Aurélie Gandit      57989
# 59853              Aurore Gruel       3647
# 59853              Aurore Gruel       3647
# 60718            Camille Perrin      46409
# 59853              Aurore Gruel       3647
# 59853              Aurore Gruel       3647
# 17503          Bouchra Ouizguen      13141
# 90781              Aurore Gruel       3647
#
#                                                            label  \
# performanceId
# 12559          \nIsmène de Yannis Ritsos mise en scène Enrico...
# 29203          \nUn œil sur la chose  chorégraphie Françoise ...
# 36399                \nLe Tribun  mise en scène Lionel Parlier\n
# 46999          \nEncore  chorégraphie Aurore Gruel conception...
# 46999          \nEncore  chorégraphie Aurore Gruel conception...
# 46999          \nEncore  chorégraphie Aurore Gruel conception...
# 46999          \nEncore  chorégraphie Aurore Gruel conception...
# 47000          \nDe pictura  chorégraphie Aurélie Gandit conc...
# 59853          \nSans territoire fixe  chorégraphie Aurore Gr...
# 59853          \nSans territoire fixe  chorégraphie Aurore Gr...
# 60718          \nL'Oripeau du Pollu  conception Camille Perrin\n
# 59853          \nSans territoire fixe  chorégraphie Aurore Gr...
# 59853          \nSans territoire fixe  chorégraphie Aurore Gr...
# 17503            \nMadame Plaza  chorégraphie Bouchra Ouizguen\n
# 90781          \nManipulation  chorégraphie Aurore Gruel conc...
#
#                           period           occurency place
# performanceId
# 12559                  \n06/04\n            [1 rep.]    \n
# 29203          \n02/02 → 05/02\n            [4 rep.]    \n
# 36399          \n20/03 → 25/03\n            [6 rep.]    \n
# 46999          \n30/01 → 02/02\n            [4 rep.]    \n
# 46999          \n30/01 → 02/02\n            [4 rep.]    \n
# 46999                  \n27/11\n            [1 rep.]    \n
# 46999                  \n27/11\n            [1 rep.]    \n
# 47000          \n19/11 → 20/11\n            [2 rep.]    \n
# 59853          \n02/10 → 03/10\n            [2 rep.]    \n
# 59853          \n02/10 → 03/10\n            [2 rep.]    \n
# 60718          \n09/12 → 12/12\n  [2 rep. + 2 scol.]    \n
# 59853          \n02/10 → 03/10\n            [2 rep.]    \n
# 59853          \n02/10 → 03/10\n            [2 rep.]    \n
# 17503                  \n01/10\n            [1 rep.]    \n
# 90781          \n07/04 → 08/04\n            [2 rep.]    \n

# %%
# 465 Le Manège de Reims
import pandas as pd

csv_file_path_pole_sud = "all_10_years_organism_465_convertInt.csv"
csv_file_path_arsenal = "all_10_years_organism_439_convertInt.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_pole_sud.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 3

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])

# %%
# 383 Grand théâtre du Luxembourg 
import pandas as pd

csv_file_path_pole_sud = "all_10_years_organism_383_convertInt.csv"
csv_file_path_arsenal = "all_10_years_organism_439_convertInt.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_pole_sud.set_index(['performanceId'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])
# Out:
#                     Unnamed: 0  organism_id                 performance  \
# performanceId year
# 28889         2011          45          465                      Salves
# 51077         2014         139          465                  Tauberbach
# 50529         2014         156          465  D'après une histoire vraie
#
#                              author  authordId  \
# performanceId year
# 28889         2011      Maguy Marin       2227
# 51077         2014     Alain Platel      14757
# 50529         2014  Christian Rizzo       7929
#
#                                                                 label  \
# performanceId year
# 28889         2011                 \nSalves  conception Maguy Marin\n
# 51077         2014  \nTauberbach  mise en scène Alain Platel conce...
# 50529         2014  \nD'après une histoire vraie  chorégraphie Chr...
#
#                                period occurency place
# performanceId year
# 28889         2011  \n17/02 → 18/02\n  [2 rep.]    \n
# 51077         2014  \n16/12 → 17/12\n  [2 rep.]    \n
# 50529         2014  \n16/04 → 17/04\n  [2 rep.]    \n

# %%
# 383 Grand théâtre du Luxembourg 
import pandas as pd

csv_file_path_pole_sud = "all_10_years_organism_383_convertInt.csv"
csv_file_path_arsenal = "all_10_years_organism_439_convertInt.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_pole_sud.set_index(['performanceId'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 9

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])
# Out:
#                Unnamed: 0  organism_id  year  \
# performanceId
# 38088                  18          383  2011
# 26064                  67          383  2012
# 43868                 110          383  2012
# 27697                  98          383  2012
# 50262                 114          383  2013
# 51317                 154          383  2013
# 54137                 198          383  2016
# 58906                 272          383  2017
# 86085                 296          383  2018
#
#                                                      performance  \
# performanceId
# 38088                                                 O Mensch !
# 26064                                                Mikrokosmos
# 43868                                                    Puz/zle
# 27697                                          Katlehong Cabaret
# 50262                                                  Les Nuits
# 51317          Barbe-Neige et les Sept Petits Cochons au bois...
# 54137                                                    L'Arbre
# 58906                                                      Pixel
# 86085                                            Requiem pour L.
#
#                                    author  authordId  \
# performanceId
# 38088                 Friedrich Nietzsche      12091
# 26064          Anne Teresa De Keersmaeker        913
# 43868                Sidi Larbi Cherkaoui       4676
# 27697                          Vusi Mdoyi      18754
# 50262                   Angelin Preljocaj       4040
# 51317                        Laura Scozzi      34227
# 54137                     Isabelle Bernay     167044
# 58906                     Mourad Merzouki       7788
# 86085                        Alain Platel      14757
#
#                                                            label  \
# performanceId
# 38088          \nO Mensch ! d'après Friedrich Nietzsche mise ...
# 26064          \nMikrokosmos  chorégraphie Anne Teresa De Kee...
# 43868             \nPuz/zle  chorégraphie Sidi Larbi Cherkaoui\n
# 27697             \nKatlehong Cabaret  chorégraphie Vusi Mdoyi\n
# 50262              \nLes Nuits  chorégraphie Angelin Preljocaj\n
# 51317          \nBarbe-Neige et les Sept Petits Cochons au bo...
# 54137          \nL'Arbre  mise en scène Isabelle Bernay…\n\n ...
# 58906          \nPixel  chorégraphie Mourad Merzouki concepti...
# 86085            \nRequiem pour L.  mise en scène Alain Platel\n
#
#                           period occurency                     place
# performanceId
# 38088                  \n11/01\n  [1 rep.]             \n (Studio)\n
# 26064                  \n27/11\n  [1 rep.]  \n”  (Arrière-scène)\n\n
# 43868                  \n14/06\n  [1 rep.]       \n (Grande Salle)\n
# 27697          \n16/04 → 17/04\n  [2 rep.]             \n (Studio)\n
# 50262          \n23/09 → 24/09\n  [2 rep.]       \n (Grande Salle)\n
# 51317          \n20/03 → 21/03\n  [2 rep.]             \n (Studio)\n
# 54137                  \n29/12\n  [3 rep.]         \n”  (Studio)\n\n
# 58906          \n14/03 → 15/03\n  [2 rep.]       \n (Grande Salle)\n
# 86085                  \n19/10\n  [1 rep.]       \n (Grande Salle)\n

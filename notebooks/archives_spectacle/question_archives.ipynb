# %% [markdown]
# # Quelles sont les 20 premiers chorégraphes les plus invités?

# %%
# ORGANISM ID DE L'ETUDE
# 439 Arsenal
# 699 CCAM [Centre culturel André Malraux] - Scène Nationale de Vandoeuvre-lès-Nancy
# 383 Grand théâtre du Luxembourg
# 1914 Carreau forbach  

# ORGANISM ID QUI PEUVENT ETRE PARTENAIRE
# 1744 Pôle sud
# 465 Le Manège de Reims


#to save the figure
#fig = ax.get_figure()
#fig.savefig('plot1.png')

# %% [markdown]
# ## A l'Arsenal

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
organismId="439"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_"+ organismId + "_danse.csv"
df_organism = pd.read_csv(csv_file_path)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

#df_organism = df_organism[df_organism['performanceId'] != 0]
#df_organism.set_index(['performanceId'], drop=True, inplace=True)

#df_organism.authordId.value_counts()

fig, ax = plt.subplots(figsize=(12,12))
ax=df_organism.groupby(["author"]).performanceId.count().sort_values(ascending=False).head(25).plot.bar()

figsize=(6,6)
ax.set_title('Les 20 chorégraphes les plus invités')
# label the y axis
ax.set_ylabel('Nombre de spectacles')
# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('Chorégraphes')
#some space for the xlabel
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(os.getcwd() + "/data/arsenal_choregraphe.png")
plt.clf()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
organismId="439"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_"+ organismId + "_danse.csv"
df_organism = pd.read_csv(csv_file_path)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

#df_organism = df_organism[df_organism['performanceId'] != 0]
#df_organism.set_index(['performanceId'], drop=True, inplace=True)

#df_organism.authordId.value_counts()

fig, ax = plt.subplots(figsize=(12,12))
df_organism.groupby(["author"]).performanceId.count().sort_values(ascending=False).head(25).plot.pie()

# %%
df_keersmaecker = df_organism[df_organism['author'].isin(["Anne Teresa De Keersmaeker"])]
df_keersmaecker
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  organism_id  year  \
# 11           19            19              21          439  2011
# 13           22            22              24          439  2011
# 24           38            38              42          439  2012
# 64           89            89             101          439  2015
# 91          135           135             161          439  2018
# 102         156           156             182          439  2018
#
#                          performance  performanceId  \
# 11                       Mikrokosmos          26064
# 13                       En atendant          27165
# 24   Dancing with the Sound Hobbyist          22187
# 64                      Golden Hours          57851
# 91                   Counter Phrases          68361
# 102                        Zeitigung          80188
#
#                          author  authordId  \
# 11   Anne Teresa De Keersmaeker        913
# 13   Anne Teresa De Keersmaeker        913
# ...

# %%
df_aurelie_GANDIT = df_organism[df_organism['author'].isin(["Aurélie Gandit"])]
df_aurelie_GANDIT

# %% [markdown]
# ## Au grand théâtre du Luxembourg

# %%
import pandas as pd
organismId="383"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_"+ organismId + "_danse.csv"
df_organism = pd.read_csv(csv_file_path)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism.set_index(['performanceId'], drop=True, inplace=True)

#df_organism.authordId.value_counts()

df_organism.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

# %%
fig, ax = plt.subplots(figsize=(12,12))
ax=df_organism.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

figsize=(6,6)
ax.set_title('Les 20 chorégraphes les plus invités')
# label the y axis
ax.set_ylabel('Nombre de spectacles')
# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('Chorégraphes')
#some space for the xlabel
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(os.getcwd() + "/data/luxembourg_choregraphe.png")
plt.clf()

# %%
df_organism= df_organism[df_organism['author'].isin(["Anne Teresa De Keersmaeker"])]
df_organism
# Out:
#                Unnamed: 0                       Genre        Durée  \
# performanceId
# 24985                  52                       Danse   1 heure 15
# 4030                   60                       Danse   1 heure 20
# 4063                   61                       Danse   1 heure 45
# 26012                  62                       Danse          NaN
# 26064                  63                       Danse          NaN
# 42237                 149                       Danse   1 heure 15
# 50566                 178                       Danse      1 heure
# 57851                 224                       Danse  2 heures 20
# 65258                 278  Danse – à partir de 13 ans   50 minutes
# 1498                  315  Danse – à partir de 12 ans   1 heure 10
# 26089                 380                       Danse   1 heure 30
# 80187                 385                       Danse   1 heure 30
# 88204                 441                       Danse          NaN
# ...

# %% [markdown]
# ## Au CCAM

# %%
import pandas as pd
organismId="699"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_"+ organismId + "_danse.csv"
df_ccam = pd.read_csv(csv_file_path)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

#df_organism = df_organism[df_organism['performanceId'] != 0]
#df_organism.set_index(['performanceId'], drop=True, inplace=True)
df_ccam.performanceId.value_counts()
#df_53079 = df_ccam[df_ccam['performanceId'].isin(["53079"])]
#df_53079
# Out:
# 53079    2
# 46999    2
# 67037    2
# 52351    1
# 60717    1
#         ..
# 3925     1
# 53078    1
# 53080    1
# 53081    1
# 81606    1
# Name: performanceId, Length: 87, dtype: int64

# %%
df_ccam.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

# %%
fig, ax = plt.subplots(figsize=(12,12))
ax=df_ccam.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

figsize=(6,6)
ax.set_title('Les 20 chorégraphes les plus invités')
# label the y axis
ax.set_ylabel('Nombre de spectacles')
# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('Chorégraphes')
#some space for the xlabel
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(os.getcwd() + "/data/ccam_choregraphe.png")
plt.clf()

# %%
df_ccam = df_ccam[df_ccam['author'].isin(["Camille Mutel"])]
df_ccam
# Out:
#     Unnamed: 0  performanceId                       Genre       Durée    Pays  \
# 23          89          47001                       Danse  20 minutes  France
# 37         121          53082                       Danse         NaN  France
# 58         184          67051  Danse – à partir de 16 ans  50 minutes  France
# 72         239          81720  Danse – à partir de 16 ans  55 minutes  France
# 89         281          99502                       Danse  50 minutes  France
#
#         typeDate        date                      organismeId organismeName  \
# 23           NaN         NaN                              NaN           NaN
# 37  Création le   2013-11-14  ?IDX_Organisme=31575&Annee=2013          CCAM
# 58  Création le   2015-12-02  ?IDX_Organisme=31575&Annee=2015          CCAM
# 72           NaN         NaN                              NaN           NaN
# 89           NaN         NaN                              NaN           NaN
#
# ...

# %% [markdown]
# ## Carreau

# %%
#1914

import pandas as pd
organismId="1914"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_"+ organismId + "_danse.csv"
df_carreau = pd.read_csv(csv_file_path)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_carreau = df_carreau[df_carreau['performanceId'] != 0]
#df_carreau.set_index(['performanceId'], drop=True, inplace=True)

#df_carreau.performanceId.value_counts()

df_carreau.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

# %%
fig, ax = plt.subplots(figsize=(12,12))
ax=df_carreau.groupby(["author"]).author.count().sort_values(ascending=False).head(20).plot.bar()

figsize=(6,6)
ax.set_title('Les 20 chorégraphes les plus invités')
# label the y axis
ax.set_ylabel('Nombre de spectacles')
# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('Chorégraphes')
#some space for the xlabel
plt.tight_layout()
fig = ax.get_figure()
fig.savefig(os.getcwd() + "/data/carreau_choregraphe.png")
plt.clf()

# %%
#Look at for the year of the choreograph the most invited
# pour arsenal
#913       6 keresmacker
#57989     5 gandit
#3647      4 gruel
#11289     4 François Chaignaud
import pandas as pd
csv_file_path = "all_10_years_organism_439_convertInt.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['authordId'].isin([11289])]
df_organism

# %%
# pour arsenal
913       6 keresmacker
57989     5 gandit
3647      4 gruel
11289     4 François Chaignaud

#pour ccam
19142      7 marie cambois
60990      5 camille mutel
3647       5 Aurore Gruel
4837       5 Olga Mesa

#pour grand theatre
913       10 keermacker
1029       8 shaekesapare
9098       6 Sasha Waltz
11883      5 wagner

#pour le carreau
# 1914 Carreau forbach 
37958     4 Mickaël Le Mer
199       4 Moliere
2717      3 Wim Vandekeybus
16498     3 Nicolas Lambert

# %%
#Pour l'Arsenal voir les utilisations de salle Grande Salle - Studio du Gouverneur  - BAM
# 439 Arsenal
import pandas as pd
csv_file_path = "all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
df_organism = df_organism[['year', 'performanceId','place']]
#remove the performance without place
df_organism = df_organism[df_organism['place'] != ""]
#df_organism.groupby("place")["year"].count()
#df_organism = df_organism[df_organism['place'].isin(["(Grande salle)"])]
repartition_place =df_organism.groupby(["place"]).performanceId.count().sort_values(ascending=False).head(20)
ax= repartition_place.plot.bar(
legend=False,
    rot=10, # rotate tick labels on x axis
    figsize=(16, 14),
    fontsize="9" # try changing to 9, 14, 26
)
# set a readable title for the plot
ax.set_title('Nombre de spectacles par salle')

# label the y axis
ax.set_ylabel('')

# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('salle')

# %% [markdown]
# # Incohérance des données

# %% [markdown]
# ## Arsenal

# %%
#Import des saisons pour l'Arsenal
import os
import pandas as pd
organismId="439"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
df_spectacle = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_spectacle = df_spectacle[df_spectacle['performanceId'] != 0]
#3 spectacles potentiellement passés plusieurs fois 59854 - 43869 - 87796
df_spectacle['performanceId'].value_counts()

df_spectacle['unique_id'] = pd.RangeIndex(stop=df_spectacle.shape[0])
df_spectacle = df_spectacle.set_index('unique_id')

df_spectacle[df_spectacle['performanceId'].isin(df_spectacle['performanceId'].value_counts()[df_spectacle['performanceId'].value_counts() > 1].index)]
# Out:
#            Unnamed: 0  organism_id  year  performance  performanceId  \
# unique_id
# 74                 83          439  2014     Tragédie          43869
# 82                 91          439  2014     Dub Love          59854
# 89                 99          439  2015     Tragédie          43869
# 90                100          439  2015     Dub Love          59854
# 160               184          439  2018  Danser Casa          87796
# 161               187          439  2018  Danser Casa          87796
#
#                        author  authordId  \
# unique_id
# 74             Olivier Dubois      10001
# 82         François Chaignaud      11289
# 89             Olivier Dubois      10001
# 90         François Chaignaud      11289
# 160               Kader Attou       9325
# 161               Kader Attou       9325
#
#                                                        label     period  \
# unique_id
# 74         \nTragédie  chorégraphie Olivier Dubois concep...  \n26/02\n
# ...

# %% [markdown]
# Dub Love et Tragédie semblent avoir été programmés en 2014 et 2015.
# Etrange
# L'article suivant https://tout-metz.com/arsenal-metz-report-spectacles-2014-4576.php parle de report de spectacle sur la saison 2015
#
#
# <img src='arsenal_report.png'>

# %%
#Supression alors des id 74 - 82 - 161
df_spectacle.drop([74 , 82, 161],inplace=True)

# %%
#Reset the index and drop the column added
df_spectacle=df_spectacle.reset_index(drop=True)
#df_spectacle['performanceId'].value_counts()
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_clean.csv"
df_spectacle.to_csv(csv_file_path_arsenal)

# %% [markdown]
# ## CCAM

# %%
import os
import pandas as pd
organismId="699"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
df_ccam = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_ccam = df_ccam[df_ccam['performanceId'] != 0]


df_ccam['unique_id'] = pd.RangeIndex(stop=df_ccam.shape[0])
df_ccam = df_ccam.set_index('unique_id')

df_duplicate = df_ccam[df_ccam['performanceId'].isin(df_ccam['performanceId'].value_counts()[df_ccam['performanceId'].value_counts() > 1].index)]

#performance - performanceId - period - year - place
df = df_duplicate[["year", "place","period", "performance", "performanceId"]]
# df.sort_values(by=['performanceId'])

# %%
df_biennale_2014 = df[df['year'].isin(['2014'])]
df_biennale_2015 = df[df['year'].isin(['2015'])]

# %%
df_biennale_2014
# Out:
#            year                        place             period  \
# unique_id
# 122        2014                          NaN  \n03/03 → 06/03\n
# 134        2014                          NaN  \n02/10 → 03/10\n
# 135        2014                          NaN          \n08/10\n
# 136        2014                          NaN  \n09/10 → 10/10\n
# 137        2014                          NaN  \n03/11 → 04/11\n
# 138        2014                          NaN          \n14/11\n
# 139        2014                          NaN          \n14/11\n
# 140        2014                          NaN  \n16/11 → 17/11\n
# 141        2014                          NaN          \n25/11\n
# 142        2014  Espace Bernard-Marie Koltès          \n26/11\n
# 143        2014                          NaN          \n30/11\n
# 144        2014                          NaN  \n02/12 → 03/12\n
#
#                              performance  performanceId
# unique_id
# ...

# %%
df_biennale_2015
# Out:
#            year                        place             period  \
# unique_id
# 146        2015                          NaN  \n02/10 → 03/10\n
# 147        2015                          NaN          \n08/10\n
# 148        2015                          NaN  \n09/10 → 10/10\n
# 149        2015                          NaN  \n03/11 → 04/11\n
# 150        2015                          NaN          \n14/11\n
# 151        2015                          NaN          \n14/11\n
# 152        2015                          NaN  \n16/11 → 17/11\n
# 153        2015                          NaN          \n25/11\n
# 154        2015  Espace Bernard-Marie Koltès          \n26/11\n
# 155        2015                          NaN          \n30/11\n
# 156        2015                          NaN  \n02/12 → 03/12\n
# 159        2015                          NaN  \n26/11 → 27/11\n
#
#                              performance  performanceId
# unique_id
# ...

# %%
La biennale ne s'est déroulée qu'en 2013 et 2015.
On le voit ici: https://www.lesarchivesduspectacle.net/?IDX_Organisme=31575
Il y a deux éditions mais rien en 2014
https://cccdanse.com/lemag/biennale-de-danse-en-lorraine-exp-edition-du-1er-octobre-au-29-novembre/
    
Et ici (issue d'un ancien site du Carreau)
        

<img src='biennale_2013_2015.png'>

# %%
#Supression des spectacles de la biennale 2014
#df_2014=df_biennale_2014.reset_index()
#id_delete=df_2014[df_2014['year'].isin(['2014'])].unique_id

df_biennale_2014.index
# Out:
# Int64Index([122, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144], dtype='int64', name='unique_id')

# %%
df_ccam.drop(df_biennale_2014.index,inplace=True)

# %%
df_duplicate = df_ccam[df_ccam['performanceId'].isin(df_ccam['performanceId'].value_counts()[df_ccam['performanceId'].value_counts() > 1].index)]

# %%
csv_file_path_ccam = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_clean.csv"
df_ccam.to_csv(csv_file_path_ccam)

# %%
import os
import pandas as pd
import re
organismId="699"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_clean.csv"
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_unique_clean_type_spectacle.csv"
df_spectacle = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})

# %%
#Filtre sur les spectacles de danse
df = pd.merge(left=df_genre, right=df_spectacle, left_on='performanceId', right_on='performanceId')
#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]
#df = df[df['performanceId'].isin(["53079"])]
#df
df.to_csv(os.getcwd() + "/data/all_10_years_organism_" + str(organismId) + '_danse.csv')

# %% [markdown]
# ## Carreau

# %%
import os
import pandas as pd
organismId="1914"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
df_carreau = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_carreau = df_carreau[df_carreau['performanceId'] != 0]


df_carreau['unique_id'] = pd.RangeIndex(stop=df_carreau.shape[0])
df_carreau = df_carreau.set_index('unique_id')

df_duplicate = df_carreau[df_carreau['performanceId'].isin(df_carreau['performanceId'].value_counts()[df_carreau['performanceId'].value_counts() > 1].index)]

#performance - performanceId - period - year - place
df = df_duplicate[["year", "place","period", "performance", "performanceId"]]
df.sort_values(by=['performanceId'])
# Out:
#            year                                              place  \
# unique_id
# 18         2010                 en tournée dans le bassin houiller
# 39         2011            en décentralisation dans l'Eurodistrict
# 67         2012  en décentralisation dans l'Eurodistrict SaarMo...
# 143        2015                                                NaN
# 162        2016                                                NaN
# 171        2017                                                NaN
# 175        2017                                                NaN
# 169        2017                                                NaN
# 174        2017                                                NaN
# 172        2017                                   Festival Loostik
# 177        2017                                                NaN
#
#                       period          performance  performanceId
# unique_id
# 18         \n23/03 → 25/03\n                Hulul          28389
# ...

# %% [markdown]
# Il y a deux doublons Les Ombres branches et Crossover
# Ils appartiennent à deux festivals
# <img src='double_festival_carreau.png'>

# %%
#drop Les ombres blanches 171 - 177 Crossover
df_carreau.drop([171,177],inplace=True)

# %%
df_duplicate = df_carreau[df_carreau['performanceId'].isin(df_carreau['performanceId'].value_counts()[df_carreau['performanceId'].value_counts() > 1].index)]
df_duplicate
# Out:
#            Unnamed: 0  organism_id  year     performance  performanceId  \
# unique_id
# 18                 20         1914  2010           Hulul          28389
# 39                 45         1914  2011           Hulul          28389
# 67                 79         1914  2012           Hulul          28389
# 143               177         1914  2015  Mad in Finland          59371
# 162               198         1914  2016  Mad in Finland          59371
# 169               207         1914  2017     Pied de nez          74341
# 174               212         1914  2017     Pied de nez          74341
#
#                    author  authordId  \
# unique_id
# 18           Arnold Lobel       9134
# 39           Arnold Lobel       9134
# 67           Arnold Lobel       9134
# 143                   NaN          0
# 162                   NaN          0
# 169        Aurélie Gandit      57989
# 174        Aurélie Gandit      57989
#
# ...

# %%
#Reset the index and drop the column added
df_carreau=df_carreau.reset_index(drop=True)

#df_spectacle['performanceId'].value_counts()
csv_file_path_carreau = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_clean.csv"
df_carreau.to_csv(csv_file_path_carreau)

# %%
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_unique_clean_type_spectacle.csv"

df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})

# %%
df_genre.shape
# Out:
# (235, 9)

# %%
df_carreau.shape
# Out:
# (239, 11)

# %%
import re
#Filtre sur les spectacles de danse
df = pd.merge(left=df_genre, right=df_carreau, left_on='performanceId', right_on='performanceId')
#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]

df.to_csv(os.getcwd() + "/data/all_10_years_organism_" + str(organismId) + '_danse.csv')

# %% [markdown]
# ## Grand théâtre

# %%
import os
import pandas as pd
organismId="383"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
df_lux = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_lux = df_lux[df_lux['performanceId'] != 0]


df_lux['unique_id'] = pd.RangeIndex(stop=df_lux.shape[0])
df_lux = df_lux.set_index('unique_id')

df_duplicate = df_lux[df_lux['performanceId'].isin(df_lux['performanceId'].value_counts()[df_lux['performanceId'].value_counts() > 1].index)]

#performance - performanceId - period - year - place
df = df_duplicate[["year", "place","period", "performance", "performanceId"]]
df.sort_values(by=['performanceId'])
# Out:
#            year                     place             period  \
# unique_id
# 241        2015                       NaN          \n26/12\n
# 242        2015                       NaN          \n26/12\n
# 226        2015                  (Studio)  \n29/09 → 02/10\n
# 299        2016                  (Studio)  \n05/01 → 07/01\n
# 349        2017            (Grande Salle)  \n15/12 → 17/12\n
# 411        2018            (Grande Salle)  \n27/12 → 29/12\n
# 446        2019   (Grande Salle)\nJoueurs          \n21/11\n
# 448        2019  (Grande Salle)\n\nMao II          \n22/11\n
#
#                          performance  performanceId
# unique_id
# 241                 Le Rêve d'Ariane          59422
# 242                 Le Rêve d'Ariane          59422
# 226                         Dom Juan          65887
# 299                         Dom Juan          65887
# 349                  Rumpelstilzchen          82911
# 411                  Rumpelstilzchen          82911
# ...

# %%
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_type_spectacle.csv"

#filtre 
df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})

df_genre.shape
# Out:
# (480, 9)

# %%
#Filtre sur les spectacles de danse
df = pd.merge(left=df_genre, right=df_lux, left_on='performanceId', right_on='performanceId')
#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]

# %%
df.to_csv(os.getcwd() + "/data/all_10_years_organism_" + str(organismId) + '_danse.csv')

# %% [markdown]
# # Utilisation des salles

# %% [markdown]
# ## A l'Arsenal

# %%
#Import des saisons pour l'Arsenal
import os
import pandas as pd
organismId="439"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_clean.csv"
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_clean_type_spectacle.csv"
df_spectacle = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_spectacle = df_spectacle[df_spectacle['performanceId'] != 0]
df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})

# %%
#set index
#df_genre.set_index(['performanceId',''], drop=True, inplace=True)
#df_spectacle.set_index(['performanceId'], drop=True, inplace=True)

# %%
df_spectacle.shape
df_spectacle["performanceId"].value_counts()
# Out:
# 46995    1
# 53079    1
# 82661    1
# 50265    1
# 90781    1
#         ..
# 22187    1
# 39082    1
# 37738    1
# 83384    1
# 67918    1
# Name: performanceId, Length: 192, dtype: int64

# %%
df_genre["performanceId"].value_counts()
# Out:
# 46995    1
# 53079    1
# 82661    1
# 50265    1
# 90781    1
#         ..
# 22187    1
# 39082    1
# 37738    1
# 83384    1
# 67918    1
# Name: performanceId, Length: 192, dtype: int64

# %%
organismId=439
df = pd.merge(left=df_spectacle, right=df_genre,how='left', left_on='performanceId', right_on='performanceId')
df["performanceId"].value_counts()
# Out:
# 46995    1
# 53079    1
# 82661    1
# 50265    1
# 90781    1
#         ..
# 22187    1
# 39082    1
# 37738    1
# 83384    1
# 67918    1
# Name: performanceId, Length: 192, dtype: int64

# %%
#Filtre sur les spectacles de danse
import re
#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]
df.to_csv(os.getcwd() + "/data/all_10_years_organism_" + str(organismId) + '_danse.csv')
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  organism_id  year                performance  \
# 0             0             0          439  2010              Babel (Words)
# 2             2             2          439  2010                 Nearly 90²
# 3             3             3          439  2010                        LOL
# 4             4             4          439  2010                   Asphalte
# 6             6             6          439  2010               Cribles/Live
# ..          ...           ...          ...   ...                        ...
# 185         185           216          439  2019                    Z'Anima
# 187         187           218          439  2019            L'Amour sorcier
# 188         188           219          439  2019  Iceberg, musique de l'eau
# 189         189           220          439  2019                Hocus Pocus
# 190         190           221          439  2019                     Kirina
#
#      performanceId                author  authordId  \
# ...

# %%
df_studio = df[df['place'].isin(["Salle Saint-Pierre-aux-Nonnains"])]
#df_organism = df_organism[df_organism['year'].isin(["2018"])]
df_studio
# Out:
#     Unnamed: 0  Unnamed: 0.1  organism_id  year performance  performanceId  \
# 67          67            76          439  2014   Dumy Moyi          50278
#
#                 author  authordId  \
# 67  François Chaignaud      11289
#
#                                                 label     period occurency  \
# 67  \nDumy Moyi  chorégraphie François Chaignaud c...  \n12/12\n  [4 rep.]
#
#                               place                       Genre       Durée  \
# 67  Salle Saint-Pierre-aux-Nonnains  Danse – à partir de 15 ans  35 minutes
#
#       Pays      typeDate        date                    organismeId  \
# 67  France  Création le   2013-07-03  ?IDX_Organisme=339&Annee=2013
#
#    organismeName   to_analyse
# 67         Agora  Création le

# %%
#Michèle Paradon besoin d'une salle avec une jauge plus petite - voir l'utilisation au cours des années

import pandas as pd
import matplotlib.pyplot as plt
organismId="439"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_danse.csv"
df_spectacle_arsenal = pd.read_csv(csv_file_path)



filter_salle = [
    "(Grande salle)",
    "(Studio du Gouverneur)",
    "(Salle de l'Esplanade)",
    "La BAM",
    "Salle Saint-Pierre-aux-Nonnains",
]



#salle_use = pd.pivot_table(
#    salle_zoom_df,
#    index='place',
#    aggfunc={'organism_id': 'count'}
#).rename(columns={'organism_id':'size'})


salle_zoom_df = df[df.place.isin(filter_salle)]
# let's reshape the data
# to make plotting easier
axes = salle_zoom_df.hist(
    column='year',
    by='place',
    sharex=True,
    sharey=True,
    figsize=(8,8),
)

plt.savefig(os.getcwd() + "/data/arsenal_salle.png", dpi=300)

# %% [markdown]
# ### Salle et danseur

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
organismId="439"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_danse.csv"
df_spectacle_arsenal = pd.read_csv(csv_file_path)
df_spectacle_arsenal.shape
# Out:
# (121, 21)

# %%
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_danse_nb_danseurs.csv"
df_danseurs_arsenal = pd.read_csv(csv_file_path)
df_danseurs_arsenal.shape
#rename spectacleId in performanceId
df_danseurs_arsenal=df_danseurs_arsenal.rename(columns={"spectacleId": "performanceId"})
df_danseurs_arsenal=df_danseurs_arsenal.rename(columns={"nb danseur": "nb_danseur"})
df = pd.merge(left=df_spectacle_arsenal, right=df_danseurs_arsenal,how='left', left_on='performanceId', right_on='performanceId')

# %%
import matplotlib.pyplot as plt
filter_salle = [
    #"(Grande salle)",
    "(Studio du Gouverneur)",
    "(Salle de l'Esplanade)",
    "La BAM",
    "Salle Saint-Pierre-aux-Nonnains",
]




danseurs_salle_zoom_df = df[df.place.isin(filter_salle)]
danseurs_salle_zoom_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  organism_id  year  \
# 7            13            13              13          439  2010
# 19           30            30              34          439  2011
# 21           33            33              37          439  2011
# 25           39            39              43          439  2012
# 32           48            48              52          439  2012
# 34           51            51              58          439  2013
# 36           53            53              60          439  2013
# 38           55            55              62          439  2013
# 47           67            67              76          439  2014
# 48           68            68              77          439  2014
# 49           70            70              79          439  2014
# 53           77            77              87          439  2014
# 57           81            81              93          439  2015
# ...

# %%
#danseurs_salle_zoom_df=danseurs_salle_zoom_df[danseurs_salle_zoom_df['place'] == '(Grande salle)']
danseurs_salle_zoom_df=danseurs_salle_zoom_df[danseurs_salle_zoom_df['nb_danseur'] == 1]

# %%
danseurs_salle_zoom_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  organism_id  year  \
# 7            13            13              13          439  2010
# 19           30            30              34          439  2011
# 25           39            39              43          439  2012
# 34           51            51              58          439  2013
# 47           67            67              76          439  2014
# 48           68            68              77          439  2014
# 57           81            81              93          439  2015
# 61           85            85              97          439  2015
# 68           96            96             108          439  2016
# 87          129           129             151          439  2017
# 92          137           137             163          439  2018
# 104         160           160             189          439  2018
# 113         176           176             207          439  2019
# ...

# %%
zoom_df=danseurs_salle_zoom_df[["performance","performanceId","author","nb_danseur","year","occurency"]]

# %%
zoom_df[["performance"]].nunique()
# Out:
# performance    15
# dtype: int64

# %%
zomm_df=zoom_df[["performance"]].nunique()
zomm_df
# Out:
# performance    15
# dtype: int64

# %%
danseurs_salle_zoom_df=danseurs_salle_zoom_df[danseurs_salle_zoom_df['place'] == '(Grande salle)']
danseurs_salle_zoom_df=danseurs_salle_zoom_df[danseurs_salle_zoom_df['nb_danseur'] > 15]

# %%
zoom_df =danseurs_salle_zoom_df[["performance","performanceId","author","nb_danseur","year","occurency"]]

# %%
zoom_df
# Out:
#           performance  performanceId             author  nb_danseur  year  \
# 51          Les Nuits          50262  Angelin Preljocaj          18  2014
# 62           Tragédie          43869     Olivier Dubois          18  2015
# 66            Opus 14          58620        Kader Attou          16  2015
# 88  Plaisirs inconnus          74937       Thomas Caley          20  2017
#
#    occurency
# 51  [2 rep.]
# 62  [1 rep.]
# 66  [1 rep.]
# 88  [1 rep.]

# %%
danseurs_salle_zoom_df['nb_danseur'].value_counts(bins=10, sort=False)
# Out:
# (-0.021, 2.0]    20
# (2.0, 4.0]       12
# (4.0, 6.0]       19
# (6.0, 8.0]       16
# (8.0, 10.0]      11
# (10.0, 12.0]      6
# (12.0, 14.0]      3
# (14.0, 16.0]      1
# (16.0, 18.0]      2
# (18.0, 20.0]      1
# Name: nb_danseur, dtype: int64

# %%
import matplotlib.pyplot as plt
filter_salle = [
    "(Grande salle)",
    "(Studio du Gouverneur)",
    "(Salle de l'Esplanade)",
    "La BAM",
    "Salle Saint-Pierre-aux-Nonnains",
]




danseurs_salle_zoom_df = df[df.place.isin(filter_salle)]
# let's reshape the data
# to make plotting easier
axes = danseurs_salle_zoom_df.hist(
    column='nb_danseur',
    by='place',
    sharex=False,
    sharey=False,
    figsize=(8,8),
)
#axes[0].set_title("test")
len(axes)
plt.suptitle('Nombre de danseurs par spectacle selon les salles')
plt.savefig(os.getcwd() + "/data/arsenal_salle_nb_danseurs.png", dpi=300)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
organismId=439
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + str(organismId) + "_danse_nb_danseurs.csv"
df_danseurs_arsenal = pd.read_csv(csv_file_path)

df_danseurs_arsenal =df_danseurs_arsenal[df_danseurs_arsenal['nb danseur'] > 15]
len(df_danseurs_arsenal)
# Out:
# 4

# %%
#merge the column

# %% [markdown]
# ## Au CCAM

# %%
import os
import pandas as pd
organismId="699"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_type_spectacle.csv"
df_spectacle = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_spectacle = df_spectacle[df_spectacle['performanceId'] != 0]
df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})
#set index
df_genre.set_index(['performanceId'], drop=True, inplace=True)
df_spectacle.set_index(['performanceId'], drop=True, inplace=True)

df = pd.merge(left=df_spectacle, right=df_genre, left_on='performanceId', right_on='performanceId')
df.shape
# Out:
# (345, 18)

# %%
df_spectacle.shape
# Out:
# (295, 10)

# %%
df_genre.shape
# Out:
# (295, 8)

# %%
#Filtre sur les spectacles de danse
import re
#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]
df.shape
# Out:
# (132, 18)

# %%
df['place'].value_counts()
# Out:
# Espace Bernard-Marie Koltès                       8
# Le Hublot                                         2
# Médiathèque Jules Verne                           2
# en diptyque avec New School                       1
# Le Préau des Arts                                 1
# en diptyque avec PlayBach                         1
# annulation 13/03 et 14/03 (Épidémie Covid-19 )    1
# en diptyque avec Man Rec                          1
# Name: place, dtype: int64

# %% [markdown]
# ### Salle et danseur

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
organismId="1914"
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_danse.csv"
df_spectacle_arsenal = pd.read_csv(csv_file_path)
df_spectacle_arsenal.shape
# Out:
# (62, 20)

# %%
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + organismId + "_danse_nb_danseurs.csv"
df_danseurs_arsenal = pd.read_csv(csv_file_path)
df_danseurs_arsenal.shape
#rename spectacleId in performanceId
df_danseurs_arsenal=df_danseurs_arsenal.rename(columns={"spectacleId": "performanceId"})
df_danseurs_arsenal=df_danseurs_arsenal.rename(columns={"nb danseur": "nb_danseur"})
df = pd.merge(left=df_spectacle_arsenal, right=df_danseurs_arsenal,how='left', left_on='performanceId', right_on='performanceId')

# %%
danseurs_salle_zoom_df=df[df['nb_danseur'] == 0]

# %%
danseurs_salle_zoom_df=danseurs_salle_zoom_df[["performance","performanceId","author","nb_danseur","year","occurency"]]
danseurs_salle_zoom_df
# Out:
#                               performance  performanceId             author  \
# 2                                     Ali          11697     Mathurin Bolze
# 5      Comment ai-je pu tenir là-dedans ?          21054    Alphonse Daudet
# 13                      L'Art de la fugue          36320    Yoann Bourgeois
# 20                              Dans Dans          44188       Lisi Estaras
# 24                              Acrobates          46467       Line Tormoen
# 26                    Liebe, schwarz-weiß          47141  Marguerite Donlon
# 28                    Six pieds sur terre          50159                NaN
# 29  Nous sommes pareils à ces crapauds...          51080         Ali Thabet
# 42                           (Dis)-cordes          66555         Jive Faury
# 43                                 Platée          66989    Jacques Autreau
# 57                     Les Bords du monde          82696   Laurent Poncelet
# ...

# %% [markdown]
# ## Carreau

# %%
import os
import pandas as pd
import re
organismId="1914"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_type_spectacle.csv"
df_spectacle = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_spectacle = df_spectacle[df_spectacle['performanceId'] != 0]
df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})
#set index
df_genre.set_index(['performanceId'], drop=True, inplace=True)
df_spectacle.set_index(['performanceId'], drop=True, inplace=True)

df = pd.merge(left=df_spectacle, right=df_genre, left_on='performanceId', right_on='performanceId')

#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]
df['place'].value_counts()
# Out:
# Festival Loostik                                2
# Saarländisches Staatstheater\n  (Sarrebrück)    1
# Castel Coucou                                   1
# dans le cadre du festival Migration             1
# dans le cadre du Tanzfestival Saar              1
# Name: place, dtype: int64

# %%
## Grand théâtre Luxembourg

# %%
import os
import pandas as pd
import re
organismId="383"
csv_file_path_spectacle = os.getcwd() + "/data/all_10_years_organism_" + organismId + ".csv"
cvs_file_path_genre= os.getcwd() + "/data/all_10_years_organism_" + organismId + "_type_spectacle.csv"
df_spectacle = pd.read_csv(csv_file_path_spectacle)
#filtre 
df_spectacle = df_spectacle[df_spectacle['performanceId'] != 0]
df_genre = pd.read_csv(cvs_file_path_genre)
#rename spectacleId in performanceId
df_genre=df_genre.rename(columns={"spectacleId": "performanceId"})
#set index
df_genre.set_index(['performanceId'], drop=True, inplace=True)
df_spectacle.set_index(['performanceId'], drop=True, inplace=True)

df = pd.merge(left=df_spectacle, right=df_genre, left_on='performanceId', right_on='performanceId')

#Filtre sur le genre - string contains danse
df=df[df['Genre'].astype(str).str.contains("Danse",flags=re.IGNORECASE, regex=True)]
df['place'].value_counts()
# Out:
# (Grande Salle)     108
# (Studio)            87
# (Arrière-scène)      8
# Name: place, dtype: int64

# %%
df_studio = df[df['place'].isin(["(Studio)"])]
#df_organism = df_organism[df_organism['year'].isin(["2018"])]
df_studio
# Out:
#                Unnamed: 0  organism_id  year              performance  \
# performanceId
# 38364                  11          383  2011              To Intimate
# 41658                  23          383  2011        Revolver besorgen
# 10120                  34          383  2011             Three Spells
# 27976                  44          383  2011             Dark Matters
# 41666                  46          383  2011               Afro-dites
# ...                   ...          ...   ...                      ...
# 89543                 452          383  2018                     Kind
# 101573                469          383  2019  The Passion of Andrea 2
# 80790                 476          383  2019                 Elektrik
# 89074                 484          383  2019                 TrapTown
# 88311                 494          383  2019                   Kirina
#
#                              author  authordId  \
# performanceId
# ...

# %% [markdown]
# # Evolution des spectacles par an

# %%
#Voir l'évolution des spectacles par an
import pandas as pd
csv_file_path = os.getcwd() + "/data/all_10_years_organism_439.csv"
df_organism = pd.read_csv(csv_file_path)
df_organism = df_organism[df_organism['performanceId'] != 0]
#df_organism.set_index(['performanceId'], drop=True, inplace=True)
#df_organism.groupby(["year"]).plot.bar()
ax=df_organism.groupby("year")["performanceId"].count().plot.bar()
# set a readable title for the plot
ax.set_title('Nombre de spectacles par an')
# label the y axis
ax.set_ylabel('')
# remove the x axis as it clutters the plot
xlabel = ax.set_xlabel('année')
df_organism.groupby("year")["performanceId"].count()
# Out:
# year
# 2010    17
# 2011    19
# 2012    15
# 2013    12
# 2014    20
# 2015    13
# 2016    22
# 2017    19
# 2018    31
# 2019    27
# Name: performanceId, dtype: int64

# %%
#Représentation du nombre de spectacles par an pour les 3 structures 
# 439 Arsenal
# 699 CCAM
# 383 grand theatre 
# 1914 CARREAU

#Voir l'évolution des spectacles par an
import pandas as pd
import matplotlib.pyplot as plt
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_danse.csv"
df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal = df_arsenal[df_arsenal['performanceId'] != 0]
df_arsenal=df_arsenal.groupby("year")["performanceId"].count()


csv_file_path_ccam = os.getcwd() + "/data/all_10_years_organism_699_danse.csv"
df_ccam = pd.read_csv(csv_file_path_ccam)
df_ccam = df_ccam[df_ccam['performanceId'] != 0]
df_ccam=df_ccam.groupby("year")["performanceId"].count()

csv_file_path_carreau = os.getcwd() + "/data/all_10_years_organism_1914_danse.csv"
df_carreau = pd.read_csv(csv_file_path_carreau)
df_carreau = df_carreau[df_carreau['performanceId'] != 0]
df_carreau=df_carreau.groupby("year")["performanceId"].count()

csv_file_path_grandtheatre = os.getcwd() + "/data/all_10_years_organism_383_danse.csv"
df_grandtheatre = pd.read_csv(csv_file_path_grandtheatre)
df_grandtheatre = df_grandtheatre[df_grandtheatre['performanceId'] != 0]
df_grandtheatre=df_grandtheatre.groupby("year")["performanceId"].count()

fig, ax = plt.subplots(figsize=(6,6))
plt.plot(df_arsenal)
plt.plot(df_ccam)
plt.plot(df_carreau)
plt.plot(df_grandtheatre)

plt.legend(["Arsenal", "CCAM","Carreau","Grand théâtre"])

ax.set_title('Nombre de spectacles par an')

fig = ax.get_figure()
fig.savefig(os.getcwd() + "/data/nb_spectacle_structure.png")
plt.clf()

# %%
# Out:
# year
# 2010     4
# 2011     1
# 2012     7
# 2013    16
# 2014     5
# 2015    16
# 2016     7
# 2017     7
# 2018    14
# 2019    13
# Name: performanceId, dtype: int64

# %%
df_carreau
# Out:
# year
# 2010     6
# 2011     6
# 2012     6
# 2013     6
# 2014     4
# 2015     7
# 2016     4
# 2017    11
# 2018     7
# 2019     5
# Name: performanceId, dtype: int64

# %%
#Remarque

#saison 2010-2011 Grand théâtre  pas complète signalée (2010-2011) sur le site
# tous genre confondus pas encore le filtre sur le genre

# %%
df_arsenal
# Out:
# year
# 2010    10
# 2011    13
# 2012    11
# 2013    11
# 2014    12
# 2015    10
# 2016    13
# 2017    11
# 2018    17
# 2019    13
# Name: performanceId, dtype: int64

# %%
df_grandtheatre
# Out:
# year
# 2010     1
# 2011    19
# 2012    24
# 2013    21
# 2014    27
# 2015    23
# 2016    23
# 2017    26
# 2018    26
# 2019    17
# Name: performanceId, dtype: int64

# %%
#Voir l'évolution des spectacles par an
import pandas as pd
import matplotlib.pyplot as plt
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_danse.csv"
df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal = df_arsenal[df_arsenal['performanceId'] != 0]



csv_file_path_ccam = os.getcwd() + "/data/all_10_years_organism_699_danse.csv"
df_ccam = pd.read_csv(csv_file_path_ccam)
df_ccam = df_ccam[df_ccam['performanceId'] != 0]

csv_file_path_carreau = os.getcwd() + "/data/all_10_years_organism_1914_danse.csv"
df_carreau = pd.read_csv(csv_file_path_carreau)
df_carreau = df_carreau[df_carreau['performanceId'] != 0]


csv_file_path_grandtheatre = os.getcwd() + "/data/all_10_years_organism_383_danse.csv"
df_grandtheatre = pd.read_csv(csv_file_path_grandtheatre)
df_grandtheatre = df_grandtheatre[df_grandtheatre['performanceId'] != 0]

# %%
  len(df_arsenal)
# Out:
# 121

# %%
df_arsenal=df_arsenal.groupby("place")["performanceId"].count()
df_arsenal
# Out:
# place
# (Grande salle)                     91
# (Salle de l'Esplanade)              6
# (Studio du Gouverneur)             17
# La BAM                              4
# Salle Saint-Pierre-aux-Nonnains     1
# Name: performanceId, dtype: int64

# %%
  len(df_ccam)
# Out:
# 90

# %%
df_ccam=df_ccam.groupby("place")["performanceId"].count()
df_ccam
# Out:
# place
# Espace Bernard-Marie Koltès                       1
# Le Hublot                                         1
# Le Préau des Arts                                 1
# Médiathèque Jules Verne                           2
# annulation 13/03 et 14/03 (Épidémie Covid-19 )    1
# en diptyque avec Man Rec                          1
# en diptyque avec New School                       1
# en diptyque avec PlayBach                         1
# Name: performanceId, dtype: int64

# %%
len(df_carreau)
# Out:
# 62

# %%
df_carreau=df_carreau.groupby("place")["performanceId"].count()
df_carreau
# Out:
# place
# Castel Coucou                                   1
# Festival Loostik                                1
# Saarländisches Staatstheater\n  (Sarrebrück)    1
# dans le cadre du Tanzfestival Saar              1
# dans le cadre du festival Migration             1
# Name: performanceId, dtype: int64

# %%
len(df_grandtheatre)
# Out:
# 207

# %%
df_grandtheatre=df_grandtheatre.groupby("place")["performanceId"].count()
df_grandtheatre
# Out:
# place
# (Arrière-scène)      8
# (Grande Salle)     108
# (Studio)            87
# Name: performanceId, dtype: int64

# %% [markdown]
# ## Grand théâtre et studio

# %%
csv_file_path_grandtheatre = os.getcwd() + "/data/all_10_years_organism_383_danse.csv"
df_grandtheatre = pd.read_csv(csv_file_path_grandtheatre)
df_grandtheatre = df_grandtheatre[df_grandtheatre['performanceId'] != 0]


df_grandtheatre = df_grandtheatre[df_grandtheatre['place'].isin(["(Arrière-scène)"])]
df_grandtheatre
# Out:
#      Unnamed: 0  performanceId  \
# 18           50          37026
# 27           61           4063
# 28           62          26012
# 29           63          26064
# 48          117          44187
# 128         320          72434
# 157         385          80187
# 158         386          85891
#
#                                                  Genre  \
# 18   Théâtre – Danse – Nouveau cirque – Musique – à...
# 27                                               Danse
# 28                                               Danse
# 29                                               Danse
# 48                             Danse – Arts numériques
# 128         Danse – Nouveau cirque – à partir de 7 ans
# 157                                              Danse
# 158                                              Danse
#
#                         Durée             Pays                typeDate  \
# 18                        NaN    Suisse/France            Création le
# ...

# %%
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + "383" + "_danse_nb_danseurs.csv"
df_danseurs = pd.read_csv(csv_file_path)

df_danseurs=df_danseurs.rename(columns={"spectacleId": "performanceId"})
df_danseurs=df_danseurs.rename(columns={"nb danseur": "nb_danseur"})
df = pd.merge(left=df_grandtheatre, right=df_danseurs,how='left', left_on='performanceId', right_on='performanceId')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-a9d94009eb68> in <module>
#       1 csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + "383" + "_danse_nb_danseurs.csv"
# ----> 2 df_danseurs = pd.read_csv(csv_file_path)
#       3
#       4 df_danseurs=df_danseurs.rename(columns={"spectacleId": "performanceId"})
#       5 df_danseurs=df_danseurs.rename(columns={"nb danseur": "nb_danseur"})
#
# ...

# %%
# Out:
#      Unnamed: 0  organism_id  year         performance  performanceId  \
# 76           76          439  2014           Dumy Moyi          50278
# 91           91          439  2014            Dub Love          59854
# 100         100          439  2015            Dub Love          59854
# 115         115          439  2017  Romances inciertos          81168
#
#                  author  authordId  \
# 76   François Chaignaud      11289
# 91   François Chaignaud      11289
# 100  François Chaignaud      11289
# 115  François Chaignaud      11289
#
#                                                  label     period occurency  \
# 76   \nDumy Moyi  chorégraphie François Chaignaud c...  \n12/12\n  [4 rep.]
# 91   \nDub Love  conception François Chaignaud…\n\n...  \n19/06\n  [1 rep.]
# 100  \nDub Love  conception François Chaignaud…\n\n...  \n04/03\n  [1 rep.]
# 115  \nRomances inciertos  chorégraphie François Ch...  \n15/12\n  [1 rep.]
#
#                                    place
# ...

# %% [markdown]
# # Regroupement dans la programmation

# %% [markdown]
# ## Lien Pôle Sud et Arsenal

# %% [markdown]
# ### Même année

# %%
# 1744 Pôle sud
# 439 Arsenal
# voir si regroupement avec les spectaclesId

import pandas as pd
import os

csv_file_path_pole_sud = os.getcwd() + "/data/all_10_years_organism_1744.csv"
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_clean.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

#df_pole_sud.set_index('performanceId', drop=True, inplace=True)
df_pole_sud.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 4

# %%
df_arsenal = df_arsenal.loc[i]
df_arsenal.sort_values(by=['year'])
df_arsenal=df_arsenal[["performance","author","period","occurency"]]

df_arsenal=df_arsenal.rename(columns={"period": "period_arsenal"})
df_arsenal=df_arsenal.rename(columns={"occurency": "occurency_arsenal"})

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])

df_pole_sud=df_pole_sud[["performance","author","period","occurency"]]

# %%
df_pole_sud=df_pole_sud.rename(columns={"period": "period_polesud"})
df_pole_sud=df_pole_sud.rename(columns={"occurency": "occurency_polesud"})
df_pole_sud=df_pole_sud[["period_polesud","occurency_polesud"]]

# %%
df = pd.merge(left=df_pole_sud, right=df_arsenal, left_on=['performanceId','year'], right_on=['performanceId','year'])
df=df[["performance","author","period_polesud","period_arsenal","occurency_polesud","occurency_arsenal"]]
# Out:
#                                         performance  \
# performanceId year
# 22187         2012  Dancing with the Sound Hobbyist
# 86085         2018                  Requiem pour L.
# 28889         2011                           Salves
# 50529         2014       D'après une histoire vraie
#
#                                         author     period_polesud  \
# performanceId year
# 22187         2012  Anne Teresa De Keersmaeker  \n27/11 → 28/11\n
# 86085         2018                Alain Platel  \n27/02 → 01/03\n
# 28889         2011                 Maguy Marin  \n16/03 → 17/03\n
# 50529         2014             Christian Rizzo  \n21/04 → 23/04\n
#
#                        period_arsenal occurency_polesud occurency_arsenal
# performanceId year
# 22187         2012          \n29/11\n          [2 rep.]          [1 rep.]
# 86085         2018  \n01/02 → 02/02\n          [3 rep.]          [2 rep.]
# 28889         2011          \n14/03\n          [2 rep.]          [1 rep.]
# ...

# %%
df.sort_values(by=['year'])
df
# Out:
#                                         performance  \
# performanceId year
# 22187         2012  Dancing with the Sound Hobbyist
# 86085         2018                  Requiem pour L.
# 28889         2011                           Salves
# 50529         2014       D'après une histoire vraie
#
#                                         author     period_polesud  \
# performanceId year
# 22187         2012  Anne Teresa De Keersmaeker  \n27/11 → 28/11\n
# 86085         2018                Alain Platel  \n27/02 → 01/03\n
# 28889         2011                 Maguy Marin  \n16/03 → 17/03\n
# 50529         2014             Christian Rizzo  \n21/04 → 23/04\n
#
#                        period_arsenal occurency_polesud occurency_arsenal
# performanceId year
# 22187         2012          \n29/11\n          [2 rep.]          [1 rep.]
# 86085         2018  \n01/02 → 02/02\n          [3 rep.]          [2 rep.]
# 28889         2011          \n14/03\n          [2 rep.]          [1 rep.]
# ...

# %% [markdown]
# ### Même performance mais pas la même année

# %%
# 1744 Pôle sud
# 439 Arsenal
# voir si regroupement avec les spectaclesId

import pandas as pd
import os

csv_file_path_pole_sud = os.getcwd() + "/data/all_10_years_organism_1744.csv"
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_clean.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_pole_sud.set_index('performanceId', drop=True, inplace=True)
#df_pole_sud.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

df_arsenal.set_index('performanceId', drop=True, inplace=True)
#df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 14

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud_arsenal=df_pole_sud.sort_values(by=['year'])
df_pole_sud_arsenal
# Out:
#                Unnamed: 0  organism_id  year  \
# performanceId
# 28889                  36         1744  2011
# 34366                  42         1744  2012
# 22187                  44         1744  2012
# 39082                  50         1744  2012
# 43869                  71         1744  2013
# 50529                 104         1744  2014
# 61225                 106         1744  2014
# 58095                  96         1744  2014
# 57252                 120         1744  2015
# 65139                 141         1744  2016
# 66093                 162         1744  2016
# 72386                 190         1744  2017
# 80425                 204         1744  2018
# 86085                 221         1744  2018
#
#                                                 performance  \
# performanceId
# 28889                                                Salves
# 34366                                              Pléiades
# 22187                       Dancing with the Sound Hobbyist
# ...

# %% [markdown]
# ### Lien coproduction arsenal et programmé à pôle Sud

# %%
import time
from datetime import datetime
import pandas as pd
import os
organismId=439
csv_file_path = os.getcwd() + "/data/all_10_years_organism_" + str(organismId) +"_type_production_danse.csv"
df_type_production_arsenal = pd.read_csv(csv_file_path)

df_type_production_arsenal = df_type_production_arsenal[df_type_production_arsenal['type_aide'] == 'Coproduction']

#where coproduction est Lux
df_type_production_arsenal = df_type_production_arsenal[df_type_production_arsenal['organismId'] == organismId]

csv_file_path_danse = os.getcwd() + "/data/all_10_years_organism_"+ str(organismId) + "_danse.csv"
df_danse = pd.read_csv(csv_file_path_danse)
df_copro_arsenal = df_danse[df_danse['performanceId'].isin(df_type_production_arsenal['performanceId'])]
df_copro_arsenal.set_index('performanceId', drop=True, inplace=True)
df_copro_arsenal
# Out:
#                Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  organism_id  year  \
# performanceId
# 28494                  16            16              18          439  2010
# 38625                  21            21              23          439  2011
# 34366                  24            24              26          439  2011
# 37816                  29            29              31          439  2011
# 38626                  30            30              34          439  2011
# 46998                  44            44              48          439  2012
# 29203                  45            45              49          439  2012
# 46999                  46            46              50          439  2012
# 47000                  48            48              52          439  2012
# 52149                  51            51              58          439  2013
# 51316                  58            58              65          439  2013
# ...

# %%
i = df_copro_arsenal.index.intersection(df_pole_sud_arsenal.index)
len(i)
# Out:
# 4

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud
# Out:
#                Unnamed: 0  organism_id  year            performance  \
# performanceId
# 34366                  42         1744  2012               Pléiades
# 57252                 120         1744  2015     Clameur des arènes
# 61225                 106         1744  2014  Bach/Passion/Johannes
# 86085                 221         1744  2018        Requiem pour L.
#
#                           author  authordId  \
# performanceId
# 34366              Alban Richard       5678
# 57252                Salia Sanou       7346
# 61225          Laurent Chétouane      74178
# 86085               Alain Platel      14757
#
#                                                            label  \
# performanceId
# 34366          \nPléiades  chorégraphie Alban Richard concept...
# 57252          \nClameur des arènes  chorégraphie Salia Sanou...
# 61225          \nBach/Passion/Johannes  chorégraphie Laurent ...
# 86085            \nRequiem pour L.  mise en scène Alain Platel\n
#
# ...

# %% [markdown]
# ## Lien Arsenal et Manège de Reims

# %% [markdown]
# ### Même année

# %%
# 465 Le Manège de Reims
import pandas as pd
import os

csv_file_path_manege =  os.getcwd() + "/data/all_10_years_organism_465.csv"
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_clean.csv"


df_manege = pd.read_csv(csv_file_path_manege)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_manege= df_manege[df_manege['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_manege.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_manege.index)
len(i)
# Out:
# 4

# %%
df_manege = df_manege.loc[i]
df_manege.sort_values(by=['year'])
# Out:
#                     Unnamed: 0  organism_id                 performance  \
# performanceId year
# 28889         2011          45          465                      Salves
# 51077         2014         139          465                  Tauberbach
# 50529         2014         156          465  D'après une histoire vraie
# 66193         2016         203          465                     Mass B.
#
#                              author  authordId  \
# performanceId year
# 28889         2011      Maguy Marin       2227
# 51077         2014     Alain Platel      14757
# 50529         2014  Christian Rizzo       7929
# 66193         2016  Béatrice Massin       9908
#
#                                                                 label  \
# performanceId year
# 28889         2011                 \nSalves  conception Maguy Marin\n
# 51077         2014  \nTauberbach  mise en scène Alain Platel conce...
# 50529         2014  \nD'après une histoire vraie  chorégraphie Chr...
# ...

# %%
df_arsenal = df_arsenal.loc[i]
df_arsenal.sort_values(by=['year'])
df_arsenal=df_arsenal[["performance","author","period","occurency"]]

df_arsenal=df_arsenal.rename(columns={"period": "period_arsenal"})
df_arsenal=df_arsenal.rename(columns={"occurency": "occurency_arsenal"})

df_manege = df_manege.loc[i]
df_manege.sort_values(by=['year'])

df_manege=df_manege[["performance","author","period","occurency"]]

df_manege=df_manege.rename(columns={"period": "period_manege"})
df_manege=df_manege.rename(columns={"occurency": "occurency_manege"})
df_manege=df_manege[["period_manege","occurency_manege"]]

# %%
df = pd.merge(left=df_manege, right=df_arsenal, left_on=['performanceId','year'], right_on=['performanceId','year'])
df=df[["performance","author","period_manege","period_arsenal","occurency_manege","occurency_arsenal"]]
df
# Out:
#                                    performance           author  \
# performanceId year
# 51077         2014                  Tauberbach     Alain Platel
# 66193         2016                     Mass B.  Béatrice Massin
# 28889         2011                      Salves      Maguy Marin
# 50529         2014  D'après une histoire vraie  Christian Rizzo
#
#                         period_manege     period_arsenal occurency_manege  \
# performanceId year
# 51077         2014  \n16/12 → 17/12\n  \n04/12 → 05/12\n         [2 rep.]
# 66193         2016  \n13/10 → 14/10\n          \n13/01\n         [2 rep.]
# 28889         2011  \n17/02 → 18/02\n          \n14/03\n         [2 rep.]
# 50529         2014  \n16/04 → 17/04\n          \n06/03\n         [2 rep.]
#
#                    occurency_arsenal
# performanceId year
# 51077         2014          [2 rep.]
# 66193         2016          [1 rep.]
# 28889         2011          [1 rep.]
# 50529         2014          [1 rep.]

# %% [markdown]
# ### Même performance

# %%
# 465 Le Manège de Reims
import pandas as pd
import os

csv_file_path_manege =  os.getcwd() + "/data/all_10_years_organism_465.csv"
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_clean.csv"


df_manege = pd.read_csv(csv_file_path_manege)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_manege= df_manege[df_manege['performanceId'] != 0]
df_manege.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

#df_manege.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

df_arsenal.set_index('performanceId', drop=True, inplace=True)
#df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_manege.index)
len(i)
# Out:
# 13

# %%
df_manege = df_manege.loc[i]
df_manege.sort_values(by=['year'])
# Out:
#                Unnamed: 0  organism_id  year  \
# performanceId
# 28889                  45          465  2011
# 37816                  83          465  2012
# 33746                  91          465  2012
# 51077                 139          465  2014
# 50529                 156          465  2014
# 59460                 184          465  2015
# 65530                 181          465  2015
# 66193                 203          465  2016
# 53079                 293          465  2017
# 82877                 296          465  2017
# 81168                 372          465  2018
# 89076                 337          465  2018
# 17503                 384          465  2019
#
#                                               performance              author  \
# performanceId
# 28889                                              Salves         Maguy Marin
# 37816                                Le Bénéfice du doute     Christian Rizzo
# ...

# %% [markdown]
# ## Lien Arsenal et Grand théâtre

# %%
# 383 Grand théâtre du Luxembourg 
import pandas as pd

csv_file_path_pole_sud = "all_10_years_organism_383_convertInt.csv"
csv_file_path_arsenal = "all_10_years_organism_439_convertInt.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_pole_sud.set_index(['performanceId'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-104-e23bfa51ae86> in <module>
#       6
#       7
# ----> 8 df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
#       9 # drop=True Delete columns to be used as the new index.
#      10 # inplace=True Modify the DataFrame in place (do not create a new object).
#
# ...

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])
# Out:
#                     Unnamed: 0  organism_id                 performance  \
# performanceId year
# 28889         2011          45          465                      Salves
# 51077         2014         139          465                  Tauberbach
# 50529         2014         156          465  D'après une histoire vraie
#
#                              author  authordId  \
# performanceId year
# 28889         2011      Maguy Marin       2227
# 51077         2014     Alain Platel      14757
# 50529         2014  Christian Rizzo       7929
#
#                                                                 label  \
# performanceId year
# 28889         2011                 \nSalves  conception Maguy Marin\n
# 51077         2014  \nTauberbach  mise en scène Alain Platel conce...
# 50529         2014  \nD'après une histoire vraie  chorégraphie Chr...
#
#                                period occurency place
# performanceId year
# 28889         2011  \n17/02 → 18/02\n  [2 rep.]    \n
# ...

# %%
# 383 Grand théâtre du Luxembourg 
import pandas as pd

csv_file_path_pole_sud = "all_10_years_organism_383_convertInt.csv"
csv_file_path_arsenal = "all_10_years_organism_439_convertInt.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)
# drop=True Delete columns to be used as the new index.
# inplace=True Modify the DataFrame in place (do not create a new object).
# verify_integrity Check the new index for duplicates. Otherwise defer the check until necessary. Setting to False will improve the performance of this method.

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]
#df_pole_sud.set_index('performanceId', drop=True, inplace=True)

#['year', 'month']

df_pole_sud.set_index(['performanceId'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

#df_arsenal.set_index('performanceId', drop=True, inplace=True)
df_arsenal.set_index(['performanceId'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 9

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])
# Out:
#                Unnamed: 0  organism_id  year  \
# performanceId
# 38088                  18          383  2011
# 26064                  67          383  2012
# 43868                 110          383  2012
# 27697                  98          383  2012
# 50262                 114          383  2013
# 51317                 154          383  2013
# 54137                 198          383  2016
# 58906                 272          383  2017
# 86085                 296          383  2018
#
#                                                      performance  \
# performanceId
# 38088                                                 O Mensch !
# 26064                                                Mikrokosmos
# 43868                                                    Puz/zle
# 27697                                          Katlehong Cabaret
# 50262                                                  Les Nuits
# 51317          Barbe-Neige et les Sept Petits Cochons au bois...
# ...

# %% [markdown]
# ## Lien Arsenal et Quartz (même capacité de salle)

# %%
# 512 Quartz
# 439 Arsenal
# voir si regroupement avec les spectaclesId

import pandas as pd
import os

csv_file_path_pole_sud = os.getcwd() + "/data/all_10_years_organism_512.csv"
csv_file_path_arsenal = os.getcwd() + "/data/all_10_years_organism_439_clean.csv"


df_pole_sud = pd.read_csv(csv_file_path_pole_sud)

df_pole_sud= df_pole_sud[df_pole_sud['performanceId'] != 0]


#['year', 'month']

df_pole_sud.set_index('performanceId', drop=True, inplace=True)
#df_pole_sud.set_index(['performanceId', 'year'], drop=True, inplace=True)

df_arsenal = pd.read_csv(csv_file_path_arsenal)
df_arsenal= df_arsenal[df_arsenal['performanceId'] != 0]

df_arsenal.set_index('performanceId', drop=True, inplace=True)
#df_arsenal.set_index(['performanceId', 'year'], drop=True, inplace=True)

#Option 1 concatenate the two dataframes and group by columns.
#result = pd.concat([df_arsenal, df_pole_sud], 1).dropna().mean(axis=1, level=0)


#Option 2 An alternative would be to find the intersecting indices with index.intersection and index with loc -
i = df_arsenal.index.intersection(df_pole_sud.index)
len(i)
# Out:
# 13

# %%
df_pole_sud = df_pole_sud.loc[i]
df_pole_sud.sort_values(by=['year'])
# Out:
#                Unnamed: 0  organism_id  year  \
# performanceId
# 33746                  28          512  2010
# 37816                 138          512  2012
# 36159                 116          512  2012
# 28889                 178          512  2013
# 50262                 165          512  2013
# 27697                 278          512  2014
# 50529                 262          512  2014
# 51317                 231          512  2014
# 59854                 254          512  2014
# 66631                 321          512  2015
# 66193                 442          512  2017
# 65530                 452          512  2017
# 81168                 506          512  2018
#
#                                                      performance  \
# performanceId
# 33746                                                   (M)imosa
# 37816                                       Le Bénéfice du doute
# 36159                                  La Face cachée de la lune
# ...
